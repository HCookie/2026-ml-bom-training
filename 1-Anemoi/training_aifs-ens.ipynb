# %%
import nci_ipynb
import os
nb_path = nci_ipynb.dir()
os.chdir(nb_path)

# %% [markdown]
# # Hands-on: Training an AIFS-ENS with Anemoi
#
# In this tutorial we will learn how to train a model like the AIFS-ENS (ensemble) model using the anemoi packages. We'll focus on the CRPS (Continuous Ranked Probability Score) based training approach, which is specifically designed for ensemble weather forecasting.
#
# This will be done on a small subset of variables on a low resolution dataset so the model converges quickly to allow for rapid exploration.
#
# **Learning Objectives**
#
# By the end of this tutorial, you will:
# - Understand the key differences between deterministic and ensemble CRPS training
# - Learn how to configure the anemoi training pipeline for ensemble models
# - Build a minimal training configuration step-by-step
# - Execute a short training run to verify everything works
#
#
# **Resources**
#
# - [Anemoi docu: CRPS-based training](https://anemoi.readthedocs.io/projects/training/en/latest/user-guide/kcrps-set-up.html)
# - [Anemoi Documentation](https://anemoi.readthedocs.io/projects/training/en/latest/)
# - [Lang et al. 2024](http://arxiv.org/abs/2412.15832)

# %% [markdown]
# ## Background: What is CRPS Training?
#
# The **Continuous Ranked Probability Score (CRPS)** is a proper scoring rule for evaluating probabilistic forecasts. In the context of ensemble weather forecasting, CRPS training allows us to train models that produce multiple ensemble members, each representing a different possible future state of the atmosphere.
#
# <img src="_resources/aifs-crps_sketch.png" alt="CRPS Sketch" width="900">
#
# ### Why Ensemble Training?
#
# - **Uncertainty Quantification**: Each ensemble member represents a different possible future
# - **Probabilistic Forecasting**: Provides uncertainty estimates alongside predictions
# - **Better Skill Scores**: Often outperforms deterministic models in terms of skill metrics
# - **Operational Use**: Essential for weather services that need to communicate forecast uncertainty

# %% [markdown]
# ## CRPS Training in Anemoi
#
# ### Key Differences: Deterministic vs CRPS Training
#
# The main components of the training pipeline need to be modified when switching from deterministic to ensemble CRPS training:
#
# | Component | Deterministic | CRPS |
# |-----------|---------------|------|
# | **Forecaster** | `GraphForecaster` | `GraphEnsForecaster` |
# | **Strategy** | `DDPGroupStrategy` | `DDPEnsGroupStrategy` |
# | **Training Loss** | `WeightedMSELoss` | `AlmostFairKernelCRPS` |
# | **Model** | `AnemoiModelEncProcDec` | `AnemoiEnsModelEncProcDec` |
# | **Datamodule** | `AnemoiDatasetsDataModule` | `AnemoiEnsDatasetsDataModule` |
#
#
# #### The AlmostFairKernelCRPS Loss
#
# The training uses the AlmostFairKernelCRPS loss function, which combines the traditional CRPS with a "fair" version:
#
# $$\text{afCRPS}_\alpha := \alpha\text{fCRPS} + (1-\alpha)\text{CRPS}$$
#
# Where $\alpha$ is a trade-off parameter between the CRPS and the fair CRPS.

# %% [markdown]
# ## Building Our Training Config
#
# Now we'll examine our training configuration step-by-step, highlighting the key differences from deterministic training. We have a minimal configuration file ready that we'll load and examine section by section.

# %%
# Let's start by importing the necessary modules
import yaml
from omegaconf import OmegaConf
from pathlib import Path

# Load our minimal configuration file
config_path = nb_path / Path("configs/aifs_ens_minimal.yaml")
with open(config_path, 'r') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# ### Step 1: Hardware Configuration
#
# The hardware configuration needs to specify the number of GPUs per ensemble, which is crucial for the ensemble training strategy.
#
# **Key Points:**
# - `num_gpus_per_ensemble`: Number of GPUs to use per ensemble (typically 1 for small setups)
# - `num_gpus_per_model`: Number of GPUs per model instance
# - Total ensemble members = `ensemble_size_per_device` × `num_gpus_per_ensemble` (we'll set this later)

# %%
# Display the system configuration section
print("System Configuration:")
print("=" * 50)
print(yaml.dump(config['system'], default_flow_style=False))
# Out:
# System Configuration:
# ==================================================
# hardware:
#   accelerator: auto
#   num_gpus_per_ensemble: 1
#   num_gpus_per_model: 1
# input:
#   dataset: /g/data/dk92/data/anemoi/aifs-ea-an-oper-0001-mars-o48-2010-2022-6h-v1-toy.zarr
#   graph: null
# output:
#   root: /scratch/${oc.env:PROJECT}/${oc.env:USER}/anemoi-output/

# %% [markdown]
# ### Step 2: Model Configuration
#
# Key model changes for CRPS-based training are:
#
# 1. **Ensemble Model Class**: Uses `AnemoiEnsModelEncProcDec` instead of `AnemoiModelEncProcDec`
#
# 2. **Noise Injector**: Each ensemble member samples random noise at every time step:
#    ```yaml
#    noise_injector:
#      _target_: anemoi.models.layers.ensemble.NoiseConditioning
#      noise_std: 1
#      noise_channels_dim: 4
#      noise_mlp_hidden_dim: 32
#    ```
#
# 3. **Conditional Layer Normalization**: The processor uses `ConditionalLayerNorm` instead of regular `LayerNorm` to condition the latent space on the noise:
#    ```yaml
#    processor:
#      layer_kernels:
#        LayerNorm:
#          _target_: anemoi.models.layers.normalization.ConditionalLayerNorm
#          normalized_shape: ${model.num_channels}
#          condition_shape: ${model.noise_injector.noise_channels_dim}
#    ```
#
#    Unlike standard layer normalization that normalizes features independently, conditional layer normalization allows the normalization to be conditioned on additional information (in this case, noise vectors).
#     - Each ensemble member gets a unique noise vector at every time step
#     - This noise is embedded and used to condition the layer normalization in the processor
#     - The conditioning allows the same model weights to produce different outputs for different ensemble members
#     - This creates diversity in the ensemble predictions while sharing computational resources
#
#
# This noise injection and conditioning is what allows each ensemble member to produce different predictions while sharing the same model weights.

# %%
# Display the model configuration section
print("Model Configuration:")
print("=" * 30)
print(yaml.dump(config['model'], default_flow_style=False))
# Out:
# Model Configuration:
# ==============================
# compile: []
# condition_on_residual: false
# decoder:
#   graph_attention_backend: pyg
# encoder:
#   graph_attention_backend: pyg
# model:
#   _target_: anemoi.models.models.AnemoiEnsModelEncProcDec
# noise_injector:
#   _target_: anemoi.models.layers.ensemble.NoiseConditioning
#   layer_kernels:
#     Activation:
#       _target_: torch.nn.GELU
#   noise_channels_dim: 4
#   noise_mlp_hidden_dim: 32
#   noise_std: 1
# num_channels: 128
# processor:
#   _target_: anemoi.models.layers.processor.TransformerProcessor
#   attention_implementation: scaled_dot_product_attention
#   layer_kernels:
#     LayerNorm:
#       _target_: anemoi.models.layers.normalization.ConditionalLayerNorm
#       autocast: false
#       condition_shape: ${model.noise_injector.noise_channels_dim}
#       normalized_shape: ${model.num_channels}
#   mlp_hidden_ratio: 4
#   num_chunks: 4
#   num_heads: 16
#   num_layers: 8
#   window_size: 512

# %% [markdown]
# ## Step 3: Data configuraation
#
# Now we configure the dataset, and loading parameters.
#
# **Key Data Parameters:**
#
# 1. **batch_size**: Control how many batches are seen
# 2. **training.datasets**: Use anemoi-datasets to open and select the training data

# %%
# Display the model configuration section
print("Dataloader Configuration:")
print("=" * 30)
print(yaml.dump(config['dataloader'], default_flow_style=False))
# Out:
# Dataloader Configuration:
# ==============================
# batch_size:
#   training: 1
#   validation: 1
# limit_batches:
#   training: 20
#   validation: 10
# training:
#   datasets:
#     data:
#       dataset_config:
#         dataset: ${dataloader.dataset}
#         select:
#         - z_1000
#         - z_500
#         - z_700
#         - z_300
#         - 2t
#         - t_850
#         - tcw
#         - z_250
#         - lsm
#         - z
#         - cp
#         - tp
#         - cos_latitude
#         - cos_longitude
#         - sin_latitude
#         - sin_longitude
#         - cos_julian_day
#         - cos_local_time
#         - sin_julian_day
#         - sin_local_time
#         - insolation
#         - lsm
#         - sdor
#         - slor
#         - z
#       end: 2020
#       start: null
# validation:
#   datasets:
#     data:
#       dataset_config: ${dataloader.training.datasets.data.dataset_config}
#       end: 2021
#       start: 2021

# %% [markdown]
# ### Step 4: Training Configuration
#
# Now we configure the training parameters, strategy, and loss function for ensemble training.
#
# **Key Training Parameters:**
#
# 1. **Model Task**: Set to `GraphEnsForecaster` (handled by the `ensemble` training default)
# 2. **Ensemble Size**: `ensemble_size_per_device: 2` means 2 ensemble members per device. Thus, the total number of ensemble members is the product of the ensemble_size_per_device and the ratio of num_gpus_per_ensemble to num_gpus_per_model .
#     ```
#     ensemble_size_per_device *  (num_gpus_per_ensemble/num_gpus_per_model) = 2 members
#    ```
#
#
# 3. **Strategy**: Uses `DDPEnsGroupStrategy` (handled by the `ensemble` training default)
# 4. **Loss Function**: `AlmostFairKernelCRPS` with `alpha=1.0` (pure fair CRPS)

# %%
# Display the training configuration section
print("Training Configuration:")
print("=" * 30)
print(yaml.dump(config['training'], default_flow_style=False))
# Out:
# Training Configuration:
# ==============================
# ensemble_size_per_device: 2
# lr:
#   iterations: ${training.max_steps}
#   min: 3e-7
#   rate: 1e-3
#   warmup: 1000
# max_steps: 200
# model_task: anemoi.training.train.tasks.GraphEnsForecaster
# strategy:
#   _target_: anemoi.training.distributed.strategy.DDPEnsGroupStrategy
#   num_gpus_per_ensemble: ${system.hardware.num_gpus_per_ensemble}
#   num_gpus_per_model: ${system.hardware.num_gpus_per_model}
#   read_group_size: ${dataloader.read_group_size}
# training_loss:
#   datasets:
#     data:
#       _target_: anemoi.training.losses.MultiscaleLossWrapper
#       keep_batch_sharded: ${model.keep_batch_sharded}
#       loss_matrices:
#       - null
#       loss_matrices_path: ${system.input.loss_matrices_path}
#       per_scale_loss:
#         _target_: anemoi.training.losses.kcrps.AlmostFairKernelCRPS
#         alpha: 0.95
#         ignore_nans: false
#         no_autocast: true
#         scalers:
#         - pressure_level
#         - general_variable
#         - nan_mask_weights
#         - node_weights
#         - time_steps
#       weights:
#       - 1.0
# validation_metrics:
#   datasets:
#     data:
#       fkcrps:
#         _target_: anemoi.training.losses.kcrps.AlmostFairKernelCRPS
#         alpha: 1.0
#         ignore_nans: false
#         scalers:
#         - node_weights
#         - time_steps
#       multiscale:
#         _target_: anemoi.training.losses.MultiscaleLossWrapper
#         keep_batch_sharded: ${model.keep_batch_sharded}
#         loss_matrices:
#         - null
#         loss_matrices_path: ${system.input.loss_matrices_path}
#         per_scale_loss:
#           _target_: anemoi.training.losses.kcrps.AlmostFairKernelCRPS
#           alpha: 1.0
#           ignore_nans: false
#           no_autocast: true
#           scalers:
#           - node_weights
#           - time_steps
#         weights:
#         - 1.0

# %% [markdown]
# ## Training Execution
#
# Now that we have our configuration ready, let's execute the training. We'll run a short training session to verify everything works correctly by running,
#
# ```bash
# export ANEMOI_BASE_SEED=42
# export ANEMOI_CONFIG_PATH="$PWD/configs"
# anemoi-training train --config-name aifs_ens_minimal
# ```

# %%
import subprocess
import sys, os 

# Set environment variables
os.environ['ANEMOI_BASE_SEED'] = '42'

os.environ['PBS_NGPUS'] = '1' # Set to 1 for single GPU training, adjust if using multiple GPUs
os.environ['PBS_NNODES'] = '1' # Set to 1 for single node training, adjust if using multiple nodes

os.environ['ANEMOI_CONFIG_PATH'] = str(nb_path / "configs")
os.environ['POSSIBLE_USER_WARNINGS'] = 'off'
os.environ['TORCH_LOGS'] = "-dynamo,-inductor"

# Execute the training using subprocess
print("Starting AIFS-ENS training...")
print("=" * 50)

process = subprocess.Popen(
    [
        "anemoi-training", "train", 
        "--config-name", "aifs_ens_minimal.yaml"
    ], 
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,  # Merge stderr into stdout
    text=True,
    bufsize=1,  # Line buffered
    universal_newlines=True
)

# Stream output
for line in iter(process.stdout.readline, ''):
    if line:
        print(line.rstrip())  # Print immediately to Jupyter cell

# Wait for completion
return_code = process.wait()

print("=" * 50)
if return_code == 0:
    print("✓ Training completed successfully!")
else:
    print(f"❌ Training failed with return code {return_code}")
# Out:
# Starting AIFS-ENS training...
# ==================================================
# 2026-04-15 11:17:17 INFO Running anemoi training command with overrides: ['--config-name', 'aifs_ens_minimal.yaml']
# 2026-04-15 11:17:29 INFO Prepending Anemoi Config Env (/home/548/hc7988/.jupyter-root/home/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi/configs) to the search path.
# 2026-04-15 11:17:29 INFO Prepending current user directory (/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi) to the search path.
# 2026-04-15 11:17:29 INFO Search path is now: [provider=anemoi-cwd-searchpath-plugin, path=/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi, provider=anemoi-env-searchpath-plugin, path=/home/548/hc7988/.jupyter-root/home/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi/configs, provider=hydra, path=pkg://hydra.conf, provider=main, path=pkg://anemoi.training/config, provider=anemoi-package-searchpath-plugin, path=pkg://anemoi.training/config]
# [2026-04-15 11:17:30,686][anemoi.training.schemas.base_schema][INFO] - adjusting save_dir path to match output mlflow logs
# [2026-04-15 11:17:30,687][anemoi.training.train.train][INFO] - Skipping config validation.
# [2026-04-15 11:17:30,719][anemoi.training.train.train][INFO] - Starting from checkpoint: False
# [2026-04-15 11:17:30,719][anemoi.training.train.train][INFO] - MLFLOW logger enabled
# [2026-04-15 11:17:30,719][anemoi.training.train.train][INFO] - Initializing MLflow logger lazily...
# [2026-04-15 11:17:31,263][anemoi.training.diagnostics.mlflow.logger][INFO] - Maximum number of params allowed to be logged is: 2000
# [2026-04-15 11:17:31,272][anemoi.training.diagnostics.mlflow.logger][INFO] - MLflow is logging offline.
# [2026-04-15 11:17:31,386][root][WARNING] - Malformed experiment 'mlruns'. Detailed error Yaml file '/scratch/dx2/hc7988/anemoi-output/logs/mlflow/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/opt/conda/envs/anemoi/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 347, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/anemoi/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 445, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/anemoi/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1588, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/anemoi/lib/python3.11/site-packages/mlflow/store/tracking/file_store.py", line 1581, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/anemoi/lib/python3.11/site-packages/mlflow/utils/yaml_utils.py", line 107, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/scratch/dx2/hc7988/anemoi-output/logs/mlflow/mlruns/meta.yaml' does not exist.
# [2026-04-15 11:17:31,723][anemoi.training.diagnostics.mlflow.logger][INFO] - Terminal Log Path: /scratch/dx2/hc7988/anemoi-output/plots/8289585ba31342adaea04eeb9dfc1591/plots/terminal_log.txt
# [2026-04-15 11:17:31,754][anemoi.training.diagnostics.mlflow.logger][WARNING] - Failed to init AMD GPU Monitor: `pyrsmi` is not installed, if you are running on an AMD GPU                 and want to log GPU metrics please run `pip install pyrsmi`.
# 2026/04/15 11:17:31 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# [2026-04-15 11:17:31,755][anemoi.training.train.train][INFO] - Run id: 8289585ba31342adaea04eeb9dfc1591
# [2026-04-15 11:17:31,756][anemoi.training.train.train][INFO] - Parent run server2server: None
# [2026-04-15 11:17:31,756][anemoi.training.train.train][INFO] - Fork run server2server: None
# [2026-04-15 11:17:31,756][anemoi.training.train.train][INFO] - Checkpoints path: {'root': PosixPath('/scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591'), 'every_n_epochs': 'anemoi-by_epoch-epoch_{epoch:03d}-step_{step:06d}', 'every_n_train_steps': 'anemoi-by_step-epoch_{epoch:03d}-step_{step:06d}', 'every_n_minutes': 'anemoi-by_time-epoch_{epoch:03d}-step_{step:06d}'}
# [2026-04-15 11:17:31,756][anemoi.training.train.train][INFO] - Plots path: /scratch/dx2/hc7988/anemoi-output/plots/8289585ba31342adaea04eeb9dfc1591
# [2026-04-15 11:17:31,756][anemoi.training.train.train][INFO] - Dry run: False
# [2026-04-15 11:17:31,757][anemoi.training.data.datamodule][INFO] - Initializing multi-dataset module with datasets: ['data']
# [2026-04-15 11:17:31,757][anemoi.training.data.datamodule][WARNING] - Falling back rollout to: 1
# [2026-04-15 11:17:31,758][anemoi.training.data.dataset][INFO] - Creating NativeGridDataset...
# [2026-04-15 11:17:31,772][anemoi.utils.config][INFO] - Using environment variable ANEMOI_CONFIG_PATH to override the anemoi config key 'path.'
# [2026-04-15 11:17:31,912][anemoi.training.data.multidataset][INFO] - Timeincrement set to 1 for data with frequency, 21600, and timestep, 21600
# [2026-04-15 11:17:31,914][anemoi.training.data.multidataset][INFO] - Dataset 'data' has 16070 valid indices
# [2026-04-15 11:17:31,914][anemoi.training.data.multidataset][INFO] - MultiDataset has 16070 valid indices after intersection.
# [2026-04-15 11:17:31,914][anemoi.training.data.multidataset][INFO] - MultiDataset initialized with 1 datasets (data), 16070 valid indices each
# [2026-04-15 11:17:31,914][anemoi.training.train.train][INFO] - Dataset 'data' - Number of variables: 23
# [2026-04-15 11:17:31,914][anemoi.training.train.train][INFO] - Dataset 'data' - Variables: ['z_1000', 'z_500', 'z_700', 'z_300', '2t', 't_850', 'tcw', 'z_250', 'cp', 'tp', 'cos_latitude', 'cos_longitude', 'sin_latitude', 'sin_longitude', 'cos_julian_day', 'cos_local_time', 'sin_julian_day', 'sin_local_time', 'insolation', 'lsm', 'sdor', 'slor', 'z']
# [2026-04-15 11:17:32,013][anemoi.training.train.train][INFO] - Dataset 'data' - Total number of prognostic variables: 10
# [2026-04-15 11:17:32,013][anemoi.training.train.train][INFO] - Dataset 'data' - Total number of auxiliary variables: 13
# [2026-04-15 11:17:32,013][anemoi.training.train.train][INFO] - Total GPU count / model group size: 1 - NB: the learning rate will be scaled by this factor!
# [2026-04-15 11:17:32,014][anemoi.training.train.train][INFO] - Effective learning rate: 1.000e-03
# [2026-04-15 11:17:33,496][anemoi.training.diagnostics.callbacks.plot][INFO] - Setting up asynchronous plotting ...
# [2026-04-15 11:17:33,497][anemoi.training.diagnostics.callbacks][INFO] - Using progress bar: <class 'pytorch_lightning.callbacks.progress.tqdm_progress.TQDMProgressBar'>
# [2026-04-15 11:17:33,503][anemoi.models.migrations.migrator][INFO] - Loading migration 1755530253_initial
# [2026-04-15 11:17:33,503][anemoi.models.migrations.migrator][INFO] - Loading migration 1762857427_deprecate_eda
# [2026-04-15 11:17:33,503][anemoi.models.migrations.migrator][INFO] - Loading migration 1762857428_chunking_fix
# [2026-04-15 11:17:33,503][anemoi.models.migrations.migrator][INFO] - Loading migration 1763479917_hardware_schema_update
# [2026-04-15 11:17:33,503][anemoi.models.migrations.migrator][INFO] - Loading migration 1763479918_refactor_mapper
# [2026-04-15 11:17:33,503][anemoi.models.migrations.migrator][INFO] - Loading migration 1767108147_move_to_multiple_datasets
# [2026-04-15 11:17:33,503][anemoi.models.migrations.migrator][INFO] - Loading migration 1773048851_fuse_multiple_perdataset_graphs
# [2026-04-15 11:17:33,509][pytorch_lightning.utilities.rank_zero][INFO] - Using 16bit Automatic Mixed Precision (AMP)
# [2026-04-15 11:17:33,521][pytorch_lightning.utilities.rank_zero][INFO] - GPU available: True (cuda), used: True
# [2026-04-15 11:17:33,521][pytorch_lightning.utilities.rank_zero][INFO] - TPU available: False, using: 0 TPU cores
# [2026-04-15 11:17:33,522][pytorch_lightning.utilities.rank_zero][INFO] - 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# [2026-04-15 11:17:34,345][anemoi.graphs.nodes.builders.from_file][INFO] - Reading the dataset from {'dataset': '/g/data/dk92/data/anemoi/aifs-ea-an-oper-0001-mars-o48-2010-2022-6h-v1-toy.zarr', 'frequency': '6h', 'drop': [], 'select': ['z_1000', 'z_500', 'z_700', 'z_300', '2t', 't_850', 'tcw', 'z_250', 'lsm', 'z', 'cp', 'tp', 'cos_latitude', 'cos_longitude', 'sin_latitude', 'sin_longitude', 'cos_julian_day', 'cos_local_time', 'sin_julian_day', 'sin_local_time', 'insolation', 'lsm', 'sdor', 'slor', 'z']}.
# [2026-04-15 11:17:35,592][anemoi.graphs.edges.builders.cutoff][INFO] - Using CutOff-Edges (with radius = 144.6 km [factor=0.60]) between data and hidden.
# [2026-04-15 11:17:35,840][anemoi.graphs.edges.builders.base][WARNING] - The 'torch-cluster' library is not installed.
# Installing 'torch-cluster' can significantly improve performance for graph creation.
# You can install it using:
#     TORCH_VERSION=$(python -c "import torch; print(torch.__version__)")
#     pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH_VERSION}.html
#
# [2026-04-15 11:17:37,754][anemoi.graphs.edges.builders.knn][INFO] - Using KNN-Edges (with 3 nearest neighbours) between hidden and data.
# [2026-04-15 11:17:37,755][anemoi.graphs.edges.builders.base][WARNING] - The 'torch-cluster' library is not installed.
# Installing 'torch-cluster' can significantly improve performance for graph creation.
# You can install it using:
#     TORCH_VERSION=$(python -c "import torch; print(torch.__version__)")
#     pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH_VERSION}.html
#
# [2026-04-15 11:17:37,802][anemoi.graphs.create][INFO] - Cleaning graph.
# [2026-04-15 11:17:37,802][anemoi.graphs.create][INFO] - _grid_reference_distance deleted from graph.
# [2026-04-15 11:17:37,803][anemoi.graphs.create][INFO] - _dataset deleted from graph.
# [2026-04-15 11:17:37,803][anemoi.graphs.create][INFO] - _grid_reference_distance deleted from graph.
# [2026-04-15 11:17:37,803][anemoi.graphs.create][WARNING] - No output path specified. The graph will not be saved.
# [2026-04-15 11:17:37,803][lightning_fabric.utilities.seed][INFO] - Seed set to 42000
# [2026-04-15 11:17:37,822][anemoi.training.train.train][INFO] - Initial seed: Rank 0, initial seed 42000, running with random seed: 42000
# [2026-04-15 11:17:39,412][anemoi.training.data.datamodule][WARNING] - Falling back rollout to: 1
# [2026-04-15 11:17:40,535][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_latitude is not normalized.
# [2026-04-15 11:17:40,536][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_longitude is not normalized.
# [2026-04-15 11:17:40,536][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_latitude is not normalized.
# [2026-04-15 11:17:40,536][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_longitude is not normalized.
# [2026-04-15 11:17:40,536][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_julian_day is not normalized.
# [2026-04-15 11:17:40,536][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_local_time is not normalized.
# [2026-04-15 11:17:40,536][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_julian_day is not normalized.
# [2026-04-15 11:17:40,536][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_local_time is not normalized.
# [2026-04-15 11:17:40,536][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: insolation is not normalized.
# [2026-04-15 11:17:40,536][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: lsm is not normalized.
# [2026-04-15 11:17:40,543][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_latitude is not normalized.
# [2026-04-15 11:17:40,543][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_longitude is not normalized.
# [2026-04-15 11:17:40,543][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_latitude is not normalized.
# [2026-04-15 11:17:40,543][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_longitude is not normalized.
# [2026-04-15 11:17:40,543][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_julian_day is not normalized.
# [2026-04-15 11:17:40,543][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_local_time is not normalized.
# [2026-04-15 11:17:40,543][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_julian_day is not normalized.
# [2026-04-15 11:17:40,543][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_local_time is not normalized.
# [2026-04-15 11:17:40,543][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: insolation is not normalized.
# [2026-04-15 11:17:40,543][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: lsm is not normalized.
# /opt/conda/envs/anemoi/lib/python3.11/site-packages/anemoi/models/preprocessing/normalizer.py:95: RuntimeWarning: divide by zero encountered in scalar divide
#   _norm_mul[i] = 1 / maximum[i]
# [2026-04-15 11:17:40,614][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-15 11:17:40,615][anemoi.models.layers.utils][INFO] - LayerNorm kernel: torch.nn.LayerNorm.
# [2026-04-15 11:17:40,615][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-15 11:17:40,616][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-15 11:17:40,617][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-15 11:17:40,650][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-15 11:17:40,651][anemoi.models.layers.utils][INFO] - LayerNorm kernel: anemoi.models.layers.normalization.ConditionalLayerNorm.
# [2026-04-15 11:17:40,651][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-15 11:17:40,652][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-15 11:17:40,653][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-15 11:17:40,653][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-15 11:17:40,658][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-15 11:17:40,660][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-15 11:17:40,662][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-15 11:17:40,664][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-15 11:17:40,665][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-15 11:17:40,667][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-15 11:17:40,669][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-15 11:17:40,676][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-15 11:17:40,677][anemoi.models.layers.utils][INFO] - LayerNorm kernel: torch.nn.LayerNorm.
# [2026-04-15 11:17:40,677][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-15 11:17:40,678][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-15 11:17:40,678][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-15 11:17:40,684][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-15 11:17:40,685][anemoi.models.layers.utils][INFO] - LayerNorm kernel: torch.nn.LayerNorm.
# [2026-04-15 11:17:40,685][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-15 11:17:40,686][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-15 11:17:40,687][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-15 11:17:40,687][anemoi.models.layers.ensemble][INFO] - processor noise channels = 4
# [2026-04-15 11:17:40,726][anemoi.training.losses.scalers.variable_level][INFO] - Variable Level Scaling: Applying ReluVariableLevelScaler scaling to pl variables ({'param': ['q', 't', 'u', 'v', 'w', 'z']})
# [2026-04-15 11:17:40,726][anemoi.training.losses.scalers.variable_level][INFO] - with slope = 0.001 and y-intercept/minimum = 0.2.
# [2026-04-15 11:17:40,752][anemoi.training.losses.multiscale][INFO] - Loss smoothing: None
# [2026-04-15 11:17:40,757][anemoi.training.losses.multiscale][INFO] - Loss smoothing: None
# [2026-04-15 11:17:40,757][anemoi.training.train.tasks.base][INFO] - GraphModule with n_step_input=2 and n_step_output=1
# [2026-04-15 11:17:40,758][anemoi.training.train.tasks.ensforecaster][INFO] - Base (config) learning rate: 1.000000e-03 -- Effective learning rate: 1.000000e-03
# [2026-04-15 11:17:40,758][anemoi.training.train.tasks.ensforecaster][INFO] - Ensemble size: per device = 2, per ens-group = 2
# [2026-04-15 11:17:40,758][anemoi.training.train.train][INFO] - The following submodules will NOT be trained: []
# [2026-04-15 11:17:40,760][anemoi.models.utils.compile][INFO] - The following modules will be compiled: []
# [2026-04-15 11:17:40,760][anemoi.training.train.train][INFO] - Recompile limit set to 32
# [2026-04-15 11:17:40,773][lightning_fabric.utilities.distributed][INFO] - Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2026-04-15 11:17:41,524][pytorch_lightning.utilities.rank_zero][INFO] - ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# [2026-04-15 11:17:42,044][anemoi.training.diagnostics.mlflow.logger][INFO] - Logging 12 parameters
# [2026-04-15 11:17:42,144][anemoi.training.distributed.strategy][INFO] - Rank 0 model_comm_group_id: 0 model_comm_group: [0] model_comm_group_rank: 0 model_comm_group.size(): 1 reader_group_id: 0 reader_group: [0] reader_group_rank: 0 reader_group_root (global): 0 model_reader_groups: [<torch.distributed.distributed_c10d.ProcessGroup object at 0x14b070060570>] reader_groups: [[<torch.distributed.distributed_c10d.ProcessGroup object at 0x14b070060570>]]
# [2026-04-15 11:17:42,226][anemoi.training.distributed.strategy][INFO] - Rank 0 ens_comm_group_id: 0 ens_comm_group: [0] ens_comm_group_rank: 0 ens_comm_group_size: 1 ens_comm_group.size(): 1 ens_comm_subgroup_id: 0 ens_comm_subgroup: [0] ens_comm_subgroup_rank: 0 ens_comm_subgroup.size(): 1
# [2026-04-15 11:17:42,226][pytorch_lightning.accelerators.cuda][INFO] - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2026-04-15 11:17:42,255][anemoi.training.train.tasks.base][INFO] - Optimizer initialized: AdamW
# [2026-04-15 11:17:42,255][anemoi.training.train.tasks.base][INFO] - Optimizer settings: {'lr': 0.001, 'betas': [0.9, 0.95], 'eps': 1e-08, 'weight_decay': 0.01, 'amsgrad': False, 'maximize': False, 'foreach': None, 'capturable': False, 'differentiable': False, 'fused': None, 'decoupled_weight_decay': True}
# [2026-04-15 11:17:42,259][lightning_fabric.utilities.seed][INFO] - [rank: 0] Seed set to 42000
# /opt/conda/envs/anemoi/lib/python3.11/site-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name    ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model   │ AnemoiModelInterface │  2.6 M │ train │     0 │
# │ 1 │ loss    │ ModuleDict           │      0 │ train │     0 │
# │ 2 │ metrics │ ModuleDict           │      0 │ train │     0 │
# └───┴─────────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 2.6 M
# Non-trainable params: 0
# Total params: 2.6 M
# Total estimated model params size (MB): 10
# Modules in train mode: 272
# Modules in eval mode: 0
# Total FLOPs: 0
# [2026-04-15 11:17:42,320][anemoi.training.diagnostics.mlflow.logger][INFO] - Logging 722 parameters
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s][2026-04-15 11:17:45,304][anemoi.training.data.datamodule][WARNING] - Falling back rollout to: 1
# [2026-04-15 11:17:45,305][anemoi.training.data.dataset][INFO] - Creating NativeGridDataset...
# [2026-04-15 11:17:45,418][anemoi.training.data.multidataset][INFO] - Timeincrement set to 1 for data with frequency, 21600, and timestep, 21600
# [2026-04-15 11:17:45,419][anemoi.training.data.multidataset][INFO] - Dataset 'data' has 1458 valid indices
# [2026-04-15 11:17:45,419][anemoi.training.data.multidataset][INFO] - MultiDataset has 1458 valid indices after intersection.
# [2026-04-15 11:17:45,419][anemoi.training.data.multidataset][INFO] - MultiDataset initialized with 1 datasets (data), 1458 valid indices each
# [2026-04-15 11:17:45,420][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_group_info(): global_rank 0, model_comm_group_id 0, model_comm_group_rank 0, model_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# [2026-04-15 11:17:45,420][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_ens_comm_group_info(): global_rank 0, ens_comm_group_id 0, ens_comm_group_rank 0, ens_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# [2026-04-15 11:17:45,472][anemoi.training.data.multidataset][INFO] - Worker 0 (pid 2041025, global_rank 0, model comm group 0)  has low/high range 0 / 183
# [2026-04-15 11:17:45,475][anemoi.training.data.multidataset][INFO] - Worker 0 (validation, pid 2041025, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:45,484][anemoi.training.data.multidataset][INFO] - Worker 1 (pid 2041026, global_rank 0, model comm group 0)  has low/high range 183 / 366
# [2026-04-15 11:17:45,485][anemoi.training.data.multidataset][INFO] - Worker 1 (validation, pid 2041026, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:45,513][anemoi.training.data.multidataset][INFO] - Worker 2 (pid 2041027, global_rank 0, model comm group 0)  has low/high range 366 / 548
# [2026-04-15 11:17:45,514][anemoi.training.data.multidataset][INFO] - Worker 2 (validation, pid 2041027, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:45,534][anemoi.training.data.multidataset][INFO] - Worker 3 (pid 2041028, global_rank 0, model comm group 0)  has low/high range 548 / 730
# [2026-04-15 11:17:45,535][anemoi.training.data.multidataset][INFO] - Worker 3 (validation, pid 2041028, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:45,563][anemoi.training.data.multidataset][INFO] - Worker 4 (pid 2041029, global_rank 0, model comm group 0)  has low/high range 730 / 912
# [2026-04-15 11:17:45,564][anemoi.training.data.multidataset][INFO] - Worker 4 (validation, pid 2041029, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:45,584][anemoi.training.data.multidataset][INFO] - Worker 5 (pid 2041030, global_rank 0, model comm group 0)  has low/high range 912 / 1094
# [2026-04-15 11:17:45,585][anemoi.training.data.multidataset][INFO] - Worker 5 (validation, pid 2041030, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:45,603][anemoi.training.data.multidataset][INFO] - Worker 6 (pid 2041031, global_rank 0, model comm group 0)  has low/high range 1094 / 1276
# [2026-04-15 11:17:45,604][anemoi.training.data.multidataset][INFO] - Worker 6 (validation, pid 2041031, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:45,703][anemoi.training.data.multidataset][INFO] - Worker 7 (pid 2041032, global_rank 0, model comm group 0)  has low/high range 1276 / 1458
# [2026-04-15 11:17:45,704][anemoi.training.data.multidataset][INFO] - Worker 7 (validation, pid 2041032, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:45,708][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
# /opt/conda/envs/anemoi/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:378: You have overridden `transfer_batch_to_device` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# /opt/conda/envs/anemoi/lib/python3.11/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:378: You have overridden `on_after_batch_transfer` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:  17%|█▋        | 1/6 [00:01<00:05,  0.87it/s]
# Sanity Checking DataLoader 0:  33%|███▎      | 2/6 [00:01<00:03,  1.27it/s]
# Sanity Checking DataLoader 0:  50%|█████     | 3/6 [00:01<00:01,  1.55it/s]
# Sanity Checking DataLoader 0:  67%|██████▋   | 4/6 [00:02<00:01,  1.75it/s]
# Sanity Checking DataLoader 0:  83%|████████▎ | 5/6 [00:02<00:00,  1.90it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 6/6 [00:02<00:00,  2.01it/s]
#
# [2026-04-15 11:17:49,168][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_group_info(): global_rank 0, model_comm_group_id 0, model_comm_group_rank 0, model_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# [2026-04-15 11:17:49,168][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_ens_comm_group_info(): global_rank 0, ens_comm_group_id 0, ens_comm_group_rank 0, ens_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# [2026-04-15 11:17:49,214][anemoi.training.data.multidataset][INFO] - Worker 0 (pid 2041061, global_rank 0, model comm group 0)  has low/high range 0 / 2009
# [2026-04-15 11:17:49,215][anemoi.training.data.multidataset][INFO] - Worker 0 (training, pid 2041061, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:49,243][anemoi.training.data.multidataset][INFO] - Worker 1 (pid 2041062, global_rank 0, model comm group 0)  has low/high range 2009 / 4018
# [2026-04-15 11:17:49,245][anemoi.training.data.multidataset][INFO] - Worker 1 (training, pid 2041062, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:49,274][anemoi.training.data.multidataset][INFO] - Worker 2 (pid 2041063, global_rank 0, model comm group 0)  has low/high range 4018 / 6027
# [2026-04-15 11:17:49,276][anemoi.training.data.multidataset][INFO] - Worker 2 (training, pid 2041063, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:49,307][anemoi.training.data.multidataset][INFO] - Worker 3 (pid 2041064, global_rank 0, model comm group 0)  has low/high range 6027 / 8036
# [2026-04-15 11:17:49,309][anemoi.training.data.multidataset][INFO] - Worker 3 (training, pid 2041064, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:49,327][anemoi.training.data.multidataset][INFO] - Worker 4 (pid 2041065, global_rank 0, model comm group 0)  has low/high range 8036 / 10045
# [2026-04-15 11:17:49,329][anemoi.training.data.multidataset][INFO] - Worker 4 (training, pid 2041065, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:49,359][anemoi.training.data.multidataset][INFO] - Worker 5 (pid 2041066, global_rank 0, model comm group 0)  has low/high range 10045 / 12054
# [2026-04-15 11:17:49,361][anemoi.training.data.multidataset][INFO] - Worker 5 (training, pid 2041066, base_seed 42000, sanity rnd 0.315034)
# [2026-04-15 11:17:49,388][anemoi.training.data.multidataset][INFO] - Worker 6 (pid 2041067, global_rank 0, model comm group 0)  has low/high range 12054 / 14062
# [2026-04-15 11:17:49,391][anemoi.training.data.multidataset][INFO] - Worker 6 (training, pid 2041067, base_seed 42000, sanity rnd 0.315034)
#
# Training: |          | 0/? [00:00<?, ?it/s][2026-04-15 11:17:49,410][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
# [2026-04-15 11:17:49,424][anemoi.training.data.multidataset][INFO] - Worker 7 (pid 2041068, global_rank 0, model comm group 0)  has low/high range 14062 / 16070
# [2026-04-15 11:17:49,425][anemoi.training.data.multidataset][INFO] - Worker 7 (training, pid 2041068, base_seed 42000, sanity rnd 0.315034)
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 0:   5%|▌         | 1/20 [00:02<00:52,  0.36it/s]
# Epoch 0:   5%|▌         | 1/20 [00:02<00:52,  0.36it/s, v_num=1591, train_multi_dataset_loss_step=20.40]
# Epoch 0:  10%|█         | 2/20 [00:04<00:38,  0.46it/s, v_num=1591, train_multi_dataset_loss_step=20.40]
# Epoch 0:  10%|█         | 2/20 [00:04<00:38,  0.46it/s, v_num=1591, train_multi_dataset_loss_step=22.00]
# Epoch 0:  15%|█▌        | 3/20 [00:06<00:34,  0.49it/s, v_num=1591, train_multi_dataset_loss_step=22.00]
# Epoch 0:  15%|█▌        | 3/20 [00:06<00:34,  0.49it/s, v_num=1591, train_multi_dataset_loss_step=21.60]
# Epoch 0:  20%|██        | 4/20 [00:07<00:30,  0.52it/s, v_num=1591, train_multi_dataset_loss_step=21.60]
# Epoch 0:  20%|██        | 4/20 [00:07<00:30,  0.52it/s, v_num=1591, train_multi_dataset_loss_step=22.20]
# Epoch 0:  25%|██▌       | 5/20 [00:09<00:27,  0.54it/s, v_num=1591, train_multi_dataset_loss_step=22.20]
# Epoch 0:  25%|██▌       | 5/20 [00:09<00:27,  0.54it/s, v_num=1591, train_multi_dataset_loss_step=21.50]
# Epoch 0:  30%|███       | 6/20 [00:10<00:25,  0.55it/s, v_num=1591, train_multi_dataset_loss_step=21.50]
# Epoch 0:  30%|███       | 6/20 [00:10<00:25,  0.55it/s, v_num=1591, train_multi_dataset_loss_step=20.80]
# Epoch 0:  35%|███▌      | 7/20 [00:12<00:23,  0.56it/s, v_num=1591, train_multi_dataset_loss_step=20.80]
# Epoch 0:  35%|███▌      | 7/20 [00:12<00:23,  0.56it/s, v_num=1591, train_multi_dataset_loss_step=20.10]
# Epoch 0:  40%|████      | 8/20 [00:14<00:21,  0.57it/s, v_num=1591, train_multi_dataset_loss_step=20.10]
# Epoch 0:  40%|████      | 8/20 [00:14<00:21,  0.57it/s, v_num=1591, train_multi_dataset_loss_step=19.80]
# Epoch 0:  45%|████▌     | 9/20 [00:16<00:20,  0.54it/s, v_num=1591, train_multi_dataset_loss_step=19.80]
# Epoch 0:  45%|████▌     | 9/20 [00:16<00:20,  0.54it/s, v_num=1591, train_multi_dataset_loss_step=20.40]
# Epoch 0:  50%|█████     | 10/20 [00:19<00:19,  0.51it/s, v_num=1591, train_multi_dataset_loss_step=20.40]
# Epoch 0:  50%|█████     | 10/20 [00:19<00:19,  0.51it/s, v_num=1591, train_multi_dataset_loss_step=18.70]
# Epoch 0:  55%|█████▌    | 11/20 [00:23<00:18,  0.48it/s, v_num=1591, train_multi_dataset_loss_step=18.70]
# Epoch 0:  55%|█████▌    | 11/20 [00:23<00:18,  0.48it/s, v_num=1591, train_multi_dataset_loss_step=18.70]
# Epoch 0:  60%|██████    | 12/20 [00:26<00:17,  0.46it/s, v_num=1591, train_multi_dataset_loss_step=18.70]
# Epoch 0:  60%|██████    | 12/20 [00:26<00:17,  0.46it/s, v_num=1591, train_multi_dataset_loss_step=18.40]
# Epoch 0:  65%|██████▌   | 13/20 [00:29<00:15,  0.44it/s, v_num=1591, train_multi_dataset_loss_step=18.40]
# Epoch 0:  65%|██████▌   | 13/20 [00:29<00:15,  0.44it/s, v_num=1591, train_multi_dataset_loss_step=18.70]
# Epoch 0:  70%|███████   | 14/20 [00:32<00:14,  0.43it/s, v_num=1591, train_multi_dataset_loss_step=18.70]
# Epoch 0:  70%|███████   | 14/20 [00:32<00:14,  0.43it/s, v_num=1591, train_multi_dataset_loss_step=18.00]
# Epoch 0:  75%|███████▌  | 15/20 [00:36<00:12,  0.42it/s, v_num=1591, train_multi_dataset_loss_step=18.00]
# Epoch 0:  75%|███████▌  | 15/20 [00:36<00:12,  0.42it/s, v_num=1591, train_multi_dataset_loss_step=16.50]
# Epoch 0:  80%|████████  | 16/20 [00:39<00:09,  0.41it/s, v_num=1591, train_multi_dataset_loss_step=16.50]
# Epoch 0:  80%|████████  | 16/20 [00:39<00:09,  0.41it/s, v_num=1591, train_multi_dataset_loss_step=16.20]
# Epoch 0:  85%|████████▌ | 17/20 [00:42<00:07,  0.40it/s, v_num=1591, train_multi_dataset_loss_step=16.20]
# Epoch 0:  85%|████████▌ | 17/20 [00:42<00:07,  0.40it/s, v_num=1591, train_multi_dataset_loss_step=15.60]
# Epoch 0:  90%|█████████ | 18/20 [00:45<00:05,  0.39it/s, v_num=1591, train_multi_dataset_loss_step=15.60]
# Epoch 0:  90%|█████████ | 18/20 [00:45<00:05,  0.39it/s, v_num=1591, train_multi_dataset_loss_step=14.20]
# Epoch 0:  95%|█████████▌| 19/20 [00:48<00:02,  0.39it/s, v_num=1591, train_multi_dataset_loss_step=14.20]
# Epoch 0:  95%|█████████▌| 19/20 [00:48<00:02,  0.39it/s, v_num=1591, train_multi_dataset_loss_step=13.20]
# Epoch 0: 100%|██████████| 20/20 [00:52<00:00,  0.38it/s, v_num=1591, train_multi_dataset_loss_step=13.20]
# Epoch 0: 100%|██████████| 20/20 [00:52<00:00,  0.38it/s, v_num=1591, train_multi_dataset_loss_step=12.60]
#
# Validation: |          | 0/? [00:00<?, ?it/s][2026-04-15 11:18:48,999][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  10%|█         | 1/10 [00:00<00:07,  1.21it/s]
#
# Validation DataLoader 0:  20%|██        | 2/10 [00:01<00:07,  1.03it/s]
#
# Validation DataLoader 0:  30%|███       | 3/10 [00:02<00:05,  1.17it/s]
#
# Validation DataLoader 0:  40%|████      | 4/10 [00:03<00:05,  1.10it/s]
#
# Validation DataLoader 0:  50%|█████     | 5/10 [00:04<00:04,  1.18it/s]
#
# Validation DataLoader 0:  60%|██████    | 6/10 [00:05<00:03,  1.15it/s]
#
# Validation DataLoader 0:  70%|███████   | 7/10 [00:05<00:02,  1.18it/s]
#
# Validation DataLoader 0:  80%|████████  | 8/10 [00:06<00:01,  1.16it/s]
#
# Validation DataLoader 0:  90%|█████████ | 9/10 [00:07<00:00,  1.18it/s]
#
# Validation DataLoader 0: 100%|██████████| 10/10 [00:08<00:00,  1.16it/s]
#
#
# Epoch 0: 100%|██████████| 20/20 [01:01<00:00,  0.33it/s, v_num=1591, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20][2026-04-15 11:18:59,579][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/inference-anemoi-by_epoch-epoch_000-step_000020.ckpt
# [2026-04-15 11:18:59,579][anemoi.utils.checkpoints][INFO] - Saving metadata to inference-anemoi-by_epoch-epoch_000-step_000020/anemoi-metadata/anemoi.json
# [2026-04-15 11:18:59,581][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to inference-anemoi-by_epoch-epoch_000-step_000020/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:18:59,581][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to inference-anemoi-by_epoch-epoch_000-step_000020/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:18:59,849][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/anemoi-by_epoch-epoch_000-step_000020.ckpt
# [2026-04-15 11:18:59,849][anemoi.utils.checkpoints][INFO] - Saving metadata to archive/anemoi-metadata/anemoi.json
# [2026-04-15 11:18:59,850][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to archive/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:18:59,851][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to archive/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:19:01,370][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/inference-last.ckpt
# [2026-04-15 11:19:01,372][anemoi.utils.checkpoints][INFO] - Saving metadata to inference-last/anemoi-metadata/anemoi.json
# [2026-04-15 11:19:01,374][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to inference-last/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:19:01,374][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to inference-last/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:19:01,613][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/last.ckpt
# [2026-04-15 11:19:01,613][anemoi.utils.checkpoints][INFO] - Saving metadata to archive/anemoi-metadata/anemoi.json
# [2026-04-15 11:19:01,615][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to archive/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:19:01,616][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to archive/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
#
# Epoch 0: 100%|██████████| 20/20 [01:04<00:00,  0.31it/s, v_num=1591, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 0:   0%|          | 0/20 [00:00<?, ?it/s, v_num=1591, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:   0%|          | 0/20 [00:00<?, ?it/s, v_num=1591, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:   5%|▌         | 1/20 [00:01<00:31,  0.61it/s, v_num=1591, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:   5%|▌         | 1/20 [00:01<00:31,  0.61it/s, v_num=1591, train_multi_dataset_loss_step=14.40, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  10%|█         | 2/20 [00:03<00:28,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=14.40, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  10%|█         | 2/20 [00:03<00:28,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  15%|█▌        | 3/20 [00:04<00:27,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  15%|█▌        | 3/20 [00:04<00:27,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=14.10, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  20%|██        | 4/20 [00:06<00:25,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=14.10, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  20%|██        | 4/20 [00:06<00:25,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=12.40, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  25%|██▌       | 5/20 [00:07<00:23,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=12.40, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  25%|██▌       | 5/20 [00:07<00:23,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=12.00, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  30%|███       | 6/20 [00:09<00:22,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=12.00, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  30%|███       | 6/20 [00:09<00:22,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=9.210, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  35%|███▌      | 7/20 [00:11<00:20,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=9.210, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  35%|███▌      | 7/20 [00:11<00:20,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=9.760, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  40%|████      | 8/20 [00:12<00:18,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=9.760, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  40%|████      | 8/20 [00:12<00:18,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=9.710, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  45%|████▌     | 9/20 [00:14<00:17,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=9.710, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  45%|████▌     | 9/20 [00:14<00:17,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=9.240, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  50%|█████     | 10/20 [00:16<00:16,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=9.240, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  50%|█████     | 10/20 [00:16<00:16,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=9.290, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  55%|█████▌    | 11/20 [00:18<00:14,  0.61it/s, v_num=1591, train_multi_dataset_loss_step=9.290, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  55%|█████▌    | 11/20 [00:18<00:14,  0.61it/s, v_num=1591, train_multi_dataset_loss_step=9.490, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  60%|██████    | 12/20 [00:20<00:13,  0.58it/s, v_num=1591, train_multi_dataset_loss_step=9.490, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  60%|██████    | 12/20 [00:20<00:13,  0.58it/s, v_num=1591, train_multi_dataset_loss_step=9.060, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  65%|██████▌   | 13/20 [00:22<00:12,  0.58it/s, v_num=1591, train_multi_dataset_loss_step=9.060, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  65%|██████▌   | 13/20 [00:22<00:12,  0.58it/s, v_num=1591, train_multi_dataset_loss_step=8.430, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  70%|███████   | 14/20 [00:24<00:10,  0.58it/s, v_num=1591, train_multi_dataset_loss_step=8.430, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  70%|███████   | 14/20 [00:24<00:10,  0.58it/s, v_num=1591, train_multi_dataset_loss_step=8.740, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  75%|███████▌  | 15/20 [00:25<00:08,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=8.740, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  75%|███████▌  | 15/20 [00:25<00:08,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=8.310, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  80%|████████  | 16/20 [00:27<00:06,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=8.310, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  80%|████████  | 16/20 [00:27<00:06,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=8.300, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  85%|████████▌ | 17/20 [00:28<00:05,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=8.300, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  85%|████████▌ | 17/20 [00:28<00:05,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=7.970, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  90%|█████████ | 18/20 [00:30<00:03,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=7.970, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  90%|█████████ | 18/20 [00:30<00:03,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=8.270, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  95%|█████████▌| 19/20 [00:32<00:01,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=8.270, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  95%|█████████▌| 19/20 [00:32<00:01,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=7.330, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1: 100%|██████████| 20/20 [00:33<00:00,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=7.330, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1: 100%|██████████| 20/20 [00:33<00:00,  0.59it/s, v_num=1591, train_multi_dataset_loss_step=7.230, val_multi_dataset_loss_step=13.70, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
#
# Validation: |          | 0/? [00:00<?, ?it/s][2026-04-15 11:19:35,297][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  10%|█         | 1/10 [00:00<00:05,  1.63it/s]
#
# Validation DataLoader 0:  20%|██        | 2/10 [00:01<00:07,  1.05it/s]
#
# Validation DataLoader 0:  30%|███       | 3/10 [00:02<00:06,  1.05it/s]
#
# Validation DataLoader 0:  40%|████      | 4/10 [00:03<00:05,  1.11it/s]
#
# Validation DataLoader 0:  50%|█████     | 5/10 [00:04<00:04,  1.10it/s]
#
# Validation DataLoader 0:  60%|██████    | 6/10 [00:05<00:03,  1.13it/s]
#
# Validation DataLoader 0:  70%|███████   | 7/10 [00:06<00:02,  1.12it/s]
#
# Validation DataLoader 0:  80%|████████  | 8/10 [00:06<00:01,  1.15it/s]
#
# Validation DataLoader 0:  90%|█████████ | 9/10 [00:07<00:00,  1.13it/s]
#
# Validation DataLoader 0: 100%|██████████| 10/10 [00:08<00:00,  1.15it/s]
#
#
# Epoch 1: 100%|██████████| 20/20 [00:42<00:00,  0.47it/s, v_num=1591, train_multi_dataset_loss_step=7.230, val_multi_dataset_loss_step=7.580, val_multi_dataset_loss_epoch=7.290, train_multi_dataset_loss_epoch=18.50][2026-04-15 11:19:45,516][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/inference-anemoi-by_epoch-epoch_001-step_000040.ckpt
# ...
# Epoch 9:  15%|█▌        | 3/20 [00:04<00:26,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=2.970, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  20%|██        | 4/20 [00:06<00:25,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=2.970, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  20%|██        | 4/20 [00:06<00:25,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.450, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  25%|██▌       | 5/20 [00:08<00:24,  0.61it/s, v_num=1591, train_multi_dataset_loss_step=3.450, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  25%|██▌       | 5/20 [00:08<00:24,  0.61it/s, v_num=1591, train_multi_dataset_loss_step=3.880, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  30%|███       | 6/20 [00:09<00:22,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=3.880, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  30%|███       | 6/20 [00:09<00:22,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=3.920, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  35%|███▌      | 7/20 [00:11<00:20,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=3.920, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  35%|███▌      | 7/20 [00:11<00:20,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=3.110, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  40%|████      | 8/20 [00:12<00:19,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=3.110, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  40%|████      | 8/20 [00:12<00:19,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=3.250, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  45%|████▌     | 9/20 [00:14<00:17,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=3.250, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  45%|████▌     | 9/20 [00:14<00:17,  0.62it/s, v_num=1591, train_multi_dataset_loss_step=3.570, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  50%|█████     | 10/20 [00:15<00:15,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.570, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  50%|█████     | 10/20 [00:15<00:15,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.020, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  55%|█████▌    | 11/20 [00:17<00:14,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.020, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  55%|█████▌    | 11/20 [00:17<00:14,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.020, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  60%|██████    | 12/20 [00:19<00:12,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.020, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  60%|██████    | 12/20 [00:19<00:12,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.080, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  65%|██████▌   | 13/20 [00:20<00:11,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.080, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  65%|██████▌   | 13/20 [00:20<00:11,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=4.250, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  70%|███████   | 14/20 [00:22<00:09,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=4.250, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  70%|███████   | 14/20 [00:22<00:09,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.580, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  75%|███████▌  | 15/20 [00:23<00:07,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.580, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  75%|███████▌  | 15/20 [00:23<00:07,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=2.690, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  80%|████████  | 16/20 [00:25<00:06,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=2.690, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  80%|████████  | 16/20 [00:25<00:06,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.260, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  85%|████████▌ | 17/20 [00:26<00:04,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.260, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  85%|████████▌ | 17/20 [00:26<00:04,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=4.180, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  90%|█████████ | 18/20 [00:28<00:03,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=4.180, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  90%|█████████ | 18/20 [00:28<00:03,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=2.780, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  95%|█████████▌| 19/20 [00:29<00:01,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=2.780, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9:  95%|█████████▌| 19/20 [00:29<00:01,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.140, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9: 100%|██████████| 20/20 [00:31<00:00,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=3.140, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
# Epoch 9: 100%|██████████| 20/20 [00:31<00:00,  0.63it/s, v_num=1591, train_multi_dataset_loss_step=4.300, val_multi_dataset_loss_step=3.450, val_multi_dataset_loss_epoch=3.150, train_multi_dataset_loss_epoch=3.430]
#
# Validation: |          | 0/? [00:00<?, ?it/s][2026-04-15 11:28:14,855][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/10 [00:00<?, ?it/s]
#
# Validation DataLoader 0:  10%|█         | 1/10 [00:00<00:03,  2.71it/s]
#
# Validation DataLoader 0:  20%|██        | 2/10 [00:00<00:03,  2.22it/s]
#
# Validation DataLoader 0:  30%|███       | 3/10 [00:01<00:02,  2.39it/s]
#
# Validation DataLoader 0:  40%|████      | 4/10 [00:01<00:02,  2.49it/s]
#
# Validation DataLoader 0:  50%|█████     | 5/10 [00:01<00:01,  2.56it/s]
#
# Validation DataLoader 0:  60%|██████    | 6/10 [00:02<00:01,  2.60it/s]
#
# Validation DataLoader 0:  70%|███████   | 7/10 [00:02<00:01,  2.63it/s]
#
# Validation DataLoader 0:  80%|████████  | 8/10 [00:03<00:00,  2.65it/s]
#
# Validation DataLoader 0:  90%|█████████ | 9/10 [00:03<00:00,  2.67it/s]
#
# Validation DataLoader 0: 100%|██████████| 10/10 [00:03<00:00,  2.69it/s]
#
#
# Epoch 9: 100%|██████████| 20/20 [00:35<00:00,  0.57it/s, v_num=1591, train_multi_dataset_loss_step=4.300, val_multi_dataset_loss_step=3.680, val_multi_dataset_loss_epoch=3.320, train_multi_dataset_loss_epoch=3.430][2026-04-15 11:28:20,117][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/inference-anemoi-by_epoch-epoch_009-step_000200.ckpt
# [2026-04-15 11:28:20,117][anemoi.utils.checkpoints][INFO] - Saving metadata to inference-anemoi-by_epoch-epoch_009-step_000200/anemoi-metadata/anemoi.json
# [2026-04-15 11:28:20,118][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to inference-anemoi-by_epoch-epoch_009-step_000200/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:20,119][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to inference-anemoi-by_epoch-epoch_009-step_000200/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:20,453][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/anemoi-by_epoch-epoch_009-step_000200.ckpt
# [2026-04-15 11:28:20,453][anemoi.utils.checkpoints][INFO] - Saving metadata to archive/anemoi-metadata/anemoi.json
# [2026-04-15 11:28:20,454][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to archive/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:20,455][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to archive/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:22,310][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/inference-last.ckpt
# [2026-04-15 11:28:22,310][anemoi.utils.checkpoints][INFO] - Saving metadata to inference-last/anemoi-metadata/anemoi.json
# [2026-04-15 11:28:22,311][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to inference-last/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:22,311][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to inference-last/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:22,508][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/last.ckpt
# [2026-04-15 11:28:22,508][anemoi.utils.checkpoints][INFO] - Saving metadata to archive/anemoi-metadata/anemoi.json
# [2026-04-15 11:28:22,510][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to archive/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:22,511][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to archive/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
#
# Epoch 9: 100%|██████████| 20/20 [00:39<00:00,  0.51it/s, v_num=1591, train_multi_dataset_loss_step=4.300, val_multi_dataset_loss_step=3.680, val_multi_dataset_loss_epoch=3.320, train_multi_dataset_loss_epoch=3.410][2026-04-15 11:28:22,520][pytorch_lightning.utilities.rank_zero][INFO] - `Trainer.fit` stopped: `max_steps=200` reached.
#
# Epoch 9: 100%|██████████| 20/20 [00:39<00:00,  0.51it/s, v_num=1591, train_multi_dataset_loss_step=4.300, val_multi_dataset_loss_step=3.680, val_multi_dataset_loss_epoch=3.320, train_multi_dataset_loss_epoch=3.410]
# [2026-04-15 11:28:24,226][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/inference-anemoi-by_time-epoch_009-step_000200.ckpt
# [2026-04-15 11:28:24,227][anemoi.utils.checkpoints][INFO] - Saving metadata to inference-anemoi-by_time-epoch_009-step_000200/anemoi-metadata/anemoi.json
# [2026-04-15 11:28:24,228][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to inference-anemoi-by_time-epoch_009-step_000200/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:24,228][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to inference-anemoi-by_time-epoch_009-step_000200/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:24,378][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/anemoi-by_time-epoch_009-step_000200.ckpt
# [2026-04-15 11:28:24,378][anemoi.utils.checkpoints][INFO] - Saving metadata to archive/anemoi-metadata/anemoi.json
# [2026-04-15 11:28:24,379][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to archive/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:24,379][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to archive/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:26,240][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/inference-last.ckpt
# [2026-04-15 11:28:26,240][anemoi.utils.checkpoints][INFO] - Saving metadata to inference-last/anemoi-metadata/anemoi.json
# [2026-04-15 11:28:26,241][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to inference-last/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:26,242][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to inference-last/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:26,444][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/8289585ba31342adaea04eeb9dfc1591/last.ckpt
# [2026-04-15 11:28:26,444][anemoi.utils.checkpoints][INFO] - Saving metadata to archive/anemoi-metadata/anemoi.json
# [2026-04-15 11:28:26,446][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to archive/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:26,447][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to archive/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-15 11:28:26,593][anemoi.training.diagnostics.callbacks.plot][INFO] - Teardown of the Plot Callback ...
# [2026-04-15 11:28:26,594][anemoi.training.diagnostics.callbacks.plot][INFO] - waiting and shutting down the executor ...
# 2026/04/15 11:28:26 INFO mlflow.system_metrics.system_metrics_monitor: Stopping system metrics monitoring...
# 2026/04/15 11:28:26 INFO mlflow.system_metrics.system_metrics_monitor: Successfully terminated system metrics monitoring!
# [2026-04-15 11:28:26,790][anemoi.training.diagnostics.mlflow.logger][INFO] - Stopping terminal log monitoring and saving buffered terminal outputs. Final status: SUCCESS
# ==================================================
# ✓ Training completed successfully!

# %% [markdown]
# ## Monitoring and Results
#
# ### MLflow logging
#
# Several metrics and parameters are logged during training. Here, we use MLflow to log results offline.
#
# In the following we use the MLflow API to plot some key metrics during training, such as:
#
# - **Training Loss**: The AlmostFairKernelCRPS loss should decrease over time
# - **Validation Metrics**: Similar to training loss, calculated on validation data
#
# *Note:* Typically the logging is done to a server and can be used interactively on a website.

# %% [markdown]
# ## Server logging
#
# Mlflow logs can be viewed in a web interface, below we skip this and directly retrieve, but if you want to do see it in that ui, move to the logging directory within this environment, and run `mlflow server`
#
# ```bash
# cd /scratch/$PROJECT/$USER/anemoi-output/logs/mlflow
# mlflow server
# ```

# %%
import mlflow
import pandas as pd
import matplotlib.pyplot as plt

run_id="8289585ba31342adaea04eeb9dfc1591" # CHANGE THIS TO YOUR RUN ID

# Start mlflow client and load run
client = mlflow.tracking.MlflowClient(tracking_uri=f"file:///scratch/{os.getenv('PROJECT')}/{os.getenv('USER')}/anemoi-output/logs/mlflow")
run = client.get_run(run_id)

print(f"Run name: {run.info.run_name}")
print("Logged metrics:")
print("=" * 50)
for k in run.data.metrics.keys():
    print(k)
# Out:
# Run name: 09237d0b-1128-46a4-926a-b74893fe38eb
# Logged metrics:
# ==================================================
# val_multi_dataset_loss_step
# lr-AdamW
# epoch
# rollout
# val_multi_dataset_loss_epoch
# train_multi_dataset_loss_epoch
# val_data_MultiscaleLossWrapper_loss_scale_0
# train_multi_dataset_loss_step
# system/system_memory_total_megabytes
# system/gpu_memory_total_megabytes
# system/disk_usage_megabytes
# system/gpu_0_power_usage_watts
# system/system_memory_usage_megabytes
# system/gpu_0_memory_usage_megabytes
# system/cpu_utilization_percentage
# system/disk_available_megabytes
# system/gpu_0_pcie_tx_megabytes
# system/gpu_0_utilization_percentage
# system/disk_usage_percentage
# system/network_transmit_megabytes
# system/system_memory_usage_percentage
# system/gpu_0_pcie_rx_megabytes
# system/network_receive_megabytes
# system/gpu_0_power_usage_percentage
# system/gpu_0_memory_usage_percentage
# val_data_multiscale_metric/data/sfc_tp/1_scale_0
# val_data_multiscale_metric/data/t_850/1_scale_0
# val_data_multiscale_metric/data/pl_t/1_scale_0
# val_data_multiscale_metric/data/z_500/1_scale_0
# val_data_multiscale_metric/data/all/1_scale_0
# val_data_multiscale_metric/data/pl_z/1_scale_0
# val_data_multiscale_metric/data/sfc_cp/1_scale_0
# val_data_multiscale_metric/data/sfc_tcw/1_scale_0
# val_data_multiscale_metric/data/sfc_2t/1_scale_0
# val_data_fkcrps_metric/data/sfc_tp/1_scale_0
# val_data_fkcrps_metric/data/t_850/1_scale_0
# val_data_fkcrps_metric/data/pl_t/1_scale_0
# val_data_fkcrps_metric/data/z_500/1_scale_0
# val_data_fkcrps_metric/data/all/1_scale_0
# val_data_fkcrps_metric/data/pl_z/1_scale_0
# val_data_fkcrps_metric/data/sfc_cp/1_scale_0
# val_data_fkcrps_metric/data/sfc_tcw/1_scale_0
# val_data_fkcrps_metric/data/sfc_2t/1_scale_0

# %%
# Plotting,
metric_names = ['train_multi_dataset_loss_step', 'val_multi_dataset_loss_epoch']

# Load data into DataFrame
data = []
for metric in metric_names:
    for entry in client.get_metric_history(run_id, metric):
        data.append({'metric': metric, 'step': entry.step, 'value': entry.value, 'time': entry.timestamp})
df = pd.DataFrame(data)

# Plot all metrics
fig, ax = plt.subplots()
for metric in df['metric'].unique():
    metric_data = df[df['metric'] == metric].sort_values('step')
    ax.plot(metric_data['step'], metric_data['value'], '-o', label=metric)
ax.legend()
ax.set_xlabel('steps')
ax.set_ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### Task 1: Change the number of ensemble members
#
# Adapt the training config and retrain the model with:
#    - a larger number of ensemble members, e.g. `ensemble_size_per_device=4`
#    - train the model for longer by increasing the number of iterations (`max_steps`) and removing the batch limit
#
# **Questions**
# - How does your loss change with the same number of steps?
# - How much longer does the training take per iteration?
# - What happens if you choose a large number of ensemble members?
#
# ***Note***:
#
# You do not need to do the training in the notebook. You can run on the console with:
# ```
# anemoi-training train --config-path PATH-TO-YOUR-CONFIG-FOLDER --config-name aifs_ens_minimal_config
# ```
#
# #### Task 1.1: Alter the config
#
# Throughout the top level config, are various `ACTIVITY:` prompts which show parts you can easily modify to alter the training behaviour, explore these and design an experiment.

# %% [markdown]
# ### Task 2: Inference of your model
#
# Run inference on the model you have trained. For that, go back to the Jupyter notebook `../4-run-AIFS/inference_aifs-ens.ipynb` and import your used checkpoint.
#
# ***Note:***
#
# You need to adapt,
# 1. The resolution of the data for your input fields to O48
#
# ```
# GRID_RESOLUTION = "O48"
# PARAM_SFC = ['2t', 'tcw', "lsm", "z", "slor", "sdor"]
# PARAM_PL = ['t', 'gh']
# LEVELS = [1000, 850, 700, 500, 300, 250]
# ```
#
# 2. Select only the input fields you need, i.e. ['z_1000', 'z_500', 'z_700', 'z_300', '2t', 't_850', 'tcw', 'z_250', 'lsm', 'z', 'sdor', 'slor']
#
#
# In case you were not able to train the checkpoint. You can find a checkpoint here:
# `/g/data/dk92/data/anemoi/inference-ens.ckpt`
