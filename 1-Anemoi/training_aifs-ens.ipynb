# %%
import nci_ipynb
import os
nb_path = nci_ipynb.dir()
os.chdir(nb_path)

# %% [markdown]
# # Hands-on: Training an AIFS-ENS with Anemoi
#
# In this tutorial we will learn how to train a model like the AIFS-ENS (ensemble) model using the anemoi packages. We'll focus on the CRPS (Continuous Ranked Probability Score) based training approach, which is specifically designed for ensemble weather forecasting.
#
# **Learning Objectives**
#
# By the end of this tutorial, you will:
# - Understand the key differences between deterministic and ensemble CRPS training
# - Learn how to configure the anemoi training pipeline for ensemble models
# - Build a minimal training configuration step-by-step
# - Execute a short training run to verify everything works
#
#
# **Resources**
#
# - [Anemoi docu: CRPS-based training](https://anemoi.readthedocs.io/projects/training/en/latest/user-guide/kcrps-set-up.html)
# - [Anemoi Documentation](https://anemoi.readthedocs.io/projects/training/en/latest/)
# - [Lang et al. 2024](http://arxiv.org/abs/2412.15832)

# %% [markdown]
# ## Background: What is CRPS Training?
#
# The **Continuous Ranked Probability Score (CRPS)** is a proper scoring rule for evaluating probabilistic forecasts. In the context of ensemble weather forecasting, CRPS training allows us to train models that produce multiple ensemble members, each representing a different possible future state of the atmosphere.
#
# <img src="_resources/aifs-crps_sketch.png" alt="CRPS Sketch" width="900">
#
# ### Why Ensemble Training?
#
# - **Uncertainty Quantification**: Each ensemble member represents a different possible future
# - **Probabilistic Forecasting**: Provides uncertainty estimates alongside predictions
# - **Better Skill Scores**: Often outperforms deterministic models in terms of skill metrics
# - **Operational Use**: Essential for weather services that need to communicate forecast uncertainty

# %% [markdown]
# ## CRPS Training in Anemoi
#
# ### Key Differences: Deterministic vs CRPS Training
#
# The main components of the training pipeline need to be modified when switching from deterministic to ensemble CRPS training:
#
# | Component | Deterministic | CRPS |
# |-----------|---------------|------|
# | **Forecaster** | `GraphForecaster` | `GraphEnsForecaster` |
# | **Strategy** | `DDPGroupStrategy` | `DDPEnsGroupStrategy` |
# | **Training Loss** | `WeightedMSELoss` | `AlmostFairKernelCRPS` |
# | **Model** | `AnemoiModelEncProcDec` | `AnemoiEnsModelEncProcDec` |
# | **Datamodule** | `AnemoiDatasetsDataModule` | `AnemoiEnsDatasetsDataModule` |
#
#
# #### The AlmostFairKernelCRPS Loss
#
# The training uses the AlmostFairKernelCRPS loss function, which combines the traditional CRPS with a "fair" version:
#
# $$\text{afCRPS}_\alpha := \alpha\text{fCRPS} + (1-\alpha)\text{CRPS}$$
#
# Where $\alpha$ is a trade-off parameter between the CRPS and the fair CRPS.

# %% [markdown]
# ## Building Our Training Config
#
# Now we'll examine our training configuration step-by-step, highlighting the key differences from deterministic training. We have a minimal configuration file ready that we'll load and examine section by section.

# %%
# Let's start by importing the necessary modules
import yaml
from omegaconf import OmegaConf
from pathlib import Path

# Load our minimal configuration file
config_path = nb_path / Path("configs/aifs_ens_minimal.yaml")
with open(config_path, 'r') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# ### Step 1: Hardware Configuration
#
# The hardware configuration needs to specify the number of GPUs per ensemble, which is crucial for the ensemble training strategy.
#
# **Key Points:**
# - `num_gpus_per_ensemble`: Number of GPUs to use per ensemble (typically 1 for small setups)
# - `num_gpus_per_model`: Number of GPUs per model instance
# - Total ensemble members = `ensemble_size_per_device` × `num_gpus_per_ensemble` (we'll set this later)

# %%
# Display the system configuration section
print("System Configuration:")
print("=" * 50)
print(yaml.dump(config['system'], default_flow_style=False))
# Out:
# System Configuration:
# ==================================================
# hardware:
#   accelerator: auto
#   num_gpus_per_ensemble: 1
#   num_gpus_per_model: 1
# input:
#   dataset: /g/data/dk92/data/aifs-ens/aifs-ea-an-oper-0001-mars-o48-2010-2022-6h-v1-toy.zarr
#   graph: null
# output:
#   root: /scratch/${oc.env:PROJECT}/${oc.env:USER}/anemoi-output/

# %% [markdown]
# ### Step 2: Model Configuration
#
# Key model changes for CRPS-based training are:
#
# 1. **Ensemble Model Class**: Uses `AnemoiEnsModelEncProcDec` instead of `AnemoiModelEncProcDec`
#
# 2. **Noise Injector**: Each ensemble member samples random noise at every time step:
#    ```yaml
#    noise_injector:
#      _target_: anemoi.models.layers.ensemble.NoiseConditioning
#      noise_std: 1
#      noise_channels_dim: 4
#      noise_mlp_hidden_dim: 32
#    ```
#
# 3. **Conditional Layer Normalization**: The processor uses `ConditionalLayerNorm` instead of regular `LayerNorm` to condition the latent space on the noise:
#    ```yaml
#    processor:
#      layer_kernels:
#        LayerNorm:
#          _target_: anemoi.models.layers.normalization.ConditionalLayerNorm
#          normalized_shape: ${model.num_channels}
#          condition_shape: ${model.noise_injector.noise_channels_dim}
#    ```
#
#    Unlike standard layer normalization that normalizes features independently, conditional layer normalization allows the normalization to be conditioned on additional information (in this case, noise vectors).
#     - Each ensemble member gets a unique noise vector at every time step
#     - This noise is embedded and used to condition the layer normalization in the processor
#     - The conditioning allows the same model weights to produce different outputs for different ensemble members
#     - This creates diversity in the ensemble predictions while sharing computational resources
#
#
# This noise injection and conditioning is what allows each ensemble member to produce different predictions while sharing the same model weights.

# %%
# Display the model configuration section
print("Model Configuration:")
print("=" * 30)
print(yaml.dump(config['model'], default_flow_style=False))
# Out:
# Model Configuration:
# ==============================
# compile: []
# condition_on_residual: false
# decoder:
#   graph_attention_backend: pyg
# encoder:
#   graph_attention_backend: pyg
# model:
#   _target_: anemoi.models.models.AnemoiEnsModelEncProcDec
# noise_injector:
#   _target_: anemoi.models.layers.ensemble.NoiseConditioning
#   layer_kernels:
#     Activation:
#       _target_: torch.nn.GELU
#   noise_channels_dim: 4
#   noise_mlp_hidden_dim: 32
#   noise_std: 1
# num_channels: 128
# processor:
#   _target_: anemoi.models.layers.processor.TransformerProcessor
#   attention_implementation: scaled_dot_product_attention
#   layer_kernels:
#     LayerNorm:
#       _target_: anemoi.models.layers.normalization.ConditionalLayerNorm
#       autocast: false
#       condition_shape: ${model.noise_injector.noise_channels_dim}
#       normalized_shape: ${model.num_channels}
#   mlp_hidden_ratio: 4
#   num_chunks: 4
#   num_heads: 16
#   num_layers: 8
#   window_size: 512

# %% [markdown]
# ## Step 3: Data configuraation
#
# Now we configure the dataset, and loading parameters.
#
# **Key Data Parameters:**
#
# 1. **batch_size**: Control how many batches are seen
# 2. **training.datasets**: Use anemoi-datasets to open and select the training data

# %%
# Display the model configuration section
print("Dataloader Configuration:")
print("=" * 30)
print(yaml.dump(config['dataloader'], default_flow_style=False))
# Out:
# Dataloader Configuration:
# ==============================
# batch_size:
#   training: 1
#   validation: 1
# limit_batches:
#   training: 20
#   validation: 10
# training:
#   datasets:
#     data:
#       dataset_config:
#         dataset: ${dataloader.dataset}
#         select:
#         - z_1000
#         - z_500
#         - z_700
#         - z_300
#         - 2t
#         - t_850
#         - tcw
#         - z_250
#         - lsm
#         - z
#         - cp
#         - tp
#         - cos_latitude
#         - cos_longitude
#         - sin_latitude
#         - sin_longitude
#         - cos_julian_day
#         - cos_local_time
#         - sin_julian_day
#         - sin_local_time
#         - insolation
#         - lsm
#         - sdor
#         - slor
#         - z
#       end: 2020
#       start: null
# validation:
#   datasets:
#     data:
#       dataset_config: ${dataloader.training.datasets.data.dataset_config}
#       end: 2021
#       start: 2021

# %% [markdown]
# ### Step 4: Training Configuration
#
# Now we configure the training parameters, strategy, and loss function for ensemble training.
#
# **Key Training Parameters:**
#
# 1. **Model Task**: Set to `GraphEnsForecaster` (handled by the `ensemble` training default)
# 2. **Ensemble Size**: `ensemble_size_per_device: 2` means 2 ensemble members per device. Thus, the total number of ensemble members is the product of the ensemble_size_per_device and the ratio of num_gpus_per_ensemble to num_gpus_per_model .
#     ```
#     ensemble_size_per_device *  (num_gpus_per_ensemble/num_gpus_per_model) = 2 members
#    ```
#
#
# 3. **Strategy**: Uses `DDPEnsGroupStrategy` (handled by the `ensemble` training default)
# 4. **Loss Function**: `AlmostFairKernelCRPS` with `alpha=1.0` (pure fair CRPS)

# %%
# Display the training configuration section
print("Training Configuration:")
print("=" * 30)
print(yaml.dump(config['training'], default_flow_style=False))
# Out:
# Training Configuration:
# ==============================
# ensemble_size_per_device: 2
# lr:
#   iterations: ${training.max_steps}
#   min: 3e-7
#   rate: 1e-3
#   warmup: 1000
# max_steps: 200
# model_task: anemoi.training.train.tasks.GraphEnsForecaster
# strategy:
#   _target_: anemoi.training.distributed.strategy.DDPEnsGroupStrategy
#   num_gpus_per_ensemble: ${system.hardware.num_gpus_per_ensemble}
#   num_gpus_per_model: ${system.hardware.num_gpus_per_model}
#   read_group_size: ${dataloader.read_group_size}
# training_loss:
#   datasets:
#     data:
#       _target_: anemoi.training.losses.MultiscaleLossWrapper
#       keep_batch_sharded: ${model.keep_batch_sharded}
#       loss_matrices:
#       - null
#       loss_matrices_path: ${system.input.loss_matrices_path}
#       per_scale_loss:
#         _target_: anemoi.training.losses.kcrps.AlmostFairKernelCRPS
#         alpha: 0.95
#         ignore_nans: false
#         no_autocast: true
#         scalers:
#         - pressure_level
#         - general_variable
#         - nan_mask_weights
#         - node_weights
#         - time_steps
#       weights:
#       - 1.0
# validation_metrics:
#   datasets:
#     data:
#       fkcrps:
#         _target_: anemoi.training.losses.kcrps.AlmostFairKernelCRPS
#         alpha: 1.0
#         ignore_nans: false
#         scalers:
#         - node_weights
#         - time_steps
#       multiscale:
#         _target_: anemoi.training.losses.MultiscaleLossWrapper
#         keep_batch_sharded: ${model.keep_batch_sharded}
#         loss_matrices:
#         - null
#         loss_matrices_path: ${system.input.loss_matrices_path}
#         per_scale_loss:
#           _target_: anemoi.training.losses.kcrps.AlmostFairKernelCRPS
#           alpha: 1.0
#           ignore_nans: false
#           no_autocast: true
#           scalers:
#           - node_weights
#           - time_steps
#         weights:
#         - 1.0

# %% [markdown]
# ## Training Execution
#
# Now that we have our configuration ready, let's execute the training. We'll run a short training session to verify everything works correctly by running,
#
# ```bash
# export ANEMOI_BASE_SEED=42
# export ANEMOI_CONFIG_PATH="$PWD/configs"
# anemoi-training train --config-name aifs_ens_minimal
# ```

# %%
import subprocess
import sys, os 

# Set environment variables
os.environ['ANEMOI_BASE_SEED'] = '42'

os.environ['PBS_NGPUS'] = '1' # Set to 1 for single GPU training, adjust if using multiple GPUs
os.environ['PBS_NNODES'] = '1' # Set to 1 for single node training, adjust if using multiple nodes

os.environ['ANEMOI_CONFIG_PATH'] = str(nb_path / "configs")
os.environ['POSSIBLE_USER_WARNINGS'] = 'off'
os.environ['TORCH_LOGS'] = "-dynamo,-inductor"

# Execute the training using subprocess
print("Starting AIFS-ENS training...")
print("=" * 50)

process = subprocess.Popen(
    [
        "anemoi-training", "train", 
        "--config-name", "aifs_ens_minimal.yaml"
    ], 
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,  # Merge stderr into stdout
    text=True,
    bufsize=1,  # Line buffered
    universal_newlines=True
)

# Stream output
for line in iter(process.stdout.readline, ''):
    if line:
        print(line.rstrip())  # Print immediately to Jupyter cell

# Wait for completion
return_code = process.wait()

print("=" * 50)
if return_code == 0:
    print("✓ Training completed successfully!")
else:
    print(f"❌ Training failed with return code {return_code}")
# Out:
# Starting AIFS-ENS training...
# ==================================================
# 2026-04-14 17:10:50 INFO Running anemoi training command with overrides: ['--config-name', 'aifs_ens_minimal.yaml']
# 2026-04-14 17:12:49 INFO Prepending Anemoi Config Env (/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi/configs) to the search path.
# 2026-04-14 17:12:49 INFO Prepending current user directory (/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi) to the search path.
# 2026-04-14 17:12:49 INFO Search path is now: [provider=anemoi-cwd-searchpath-plugin, path=/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi, provider=anemoi-env-searchpath-plugin, path=/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi/configs, provider=hydra, path=pkg://hydra.conf, provider=main, path=pkg://anemoi.training/config, provider=anemoi-package-searchpath-plugin, path=pkg://anemoi.training/config]
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# [2026-04-14 17:12:50,786][anemoi.training.schemas.base_schema][INFO] - adjusting save_dir path to match output mlflow logs
# [2026-04-14 17:12:50,787][anemoi.training.train.train][INFO] - Skipping config validation.
# [2026-04-14 17:12:50,923][anemoi.training.train.train][INFO] - Starting from checkpoint: False
# [2026-04-14 17:12:50,924][anemoi.training.train.train][INFO] - MLFLOW logger enabled
# [2026-04-14 17:12:50,925][anemoi.training.train.train][INFO] - Initializing MLflow logger lazily...
# [2026-04-14 17:13:00,620][anemoi.training.diagnostics.mlflow.logger][INFO] - Maximum number of params allowed to be logged is: 2000
# [2026-04-14 17:13:00,671][anemoi.training.diagnostics.mlflow.logger][INFO] - MLflow is logging offline.
# [2026-04-14 17:13:00,759][root][WARNING] - Malformed experiment 'mlruns'. Detailed error Yaml file '/scratch/dx2/hc7988/anemoi-output/logs/mlflow/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/mlflow/store/tracking/file_store.py", line 347, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/mlflow/store/tracking/file_store.py", line 445, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/mlflow/store/tracking/file_store.py", line 1588, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/mlflow/store/tracking/file_store.py", line 1581, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/mlflow/utils/yaml_utils.py", line 107, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/scratch/dx2/hc7988/anemoi-output/logs/mlflow/mlruns/meta.yaml' does not exist.
# [2026-04-14 17:13:03,312][anemoi.training.diagnostics.mlflow.logger][INFO] - Terminal Log Path: /scratch/dx2/hc7988/anemoi-output/plots/7ac826b0a4c343d5980957a87093330b/plots/terminal_log.txt
# 2026/04/14 17:13:03 INFO mlflow.system_metrics.system_metrics_monitor: Skip logging GPU metrics. Set logger level to DEBUG for more details.
# [2026-04-14 17:13:03,694][anemoi.training.diagnostics.mlflow.logger][WARNING] - Failed to init Nvidia GPU Monitor: Failed to initalize Nvidia GPU monitor:
# [2026-04-14 17:13:03,696][anemoi.training.diagnostics.mlflow.logger][WARNING] - Failed to init AMD GPU Monitor: `pyrsmi` is not installed, if you are running on an AMD GPU                 and want to log GPU metrics please run `pip install pyrsmi`.
# 2026/04/14 17:13:03 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# [2026-04-14 17:13:03,700][anemoi.training.train.train][INFO] - Run id: 7ac826b0a4c343d5980957a87093330b
# [2026-04-14 17:13:03,701][anemoi.training.train.train][INFO] - Parent run server2server: None
# [2026-04-14 17:13:03,701][anemoi.training.train.train][INFO] - Fork run server2server: None
# [2026-04-14 17:13:03,702][anemoi.training.train.train][INFO] - Checkpoints path: {'root': PosixPath('/scratch/dx2/hc7988/anemoi-output/checkpoint/7ac826b0a4c343d5980957a87093330b'), 'every_n_epochs': 'anemoi-by_epoch-epoch_{epoch:03d}-step_{step:06d}', 'every_n_train_steps': 'anemoi-by_step-epoch_{epoch:03d}-step_{step:06d}', 'every_n_minutes': 'anemoi-by_time-epoch_{epoch:03d}-step_{step:06d}'}
# [2026-04-14 17:13:03,703][anemoi.training.train.train][INFO] - Plots path: /scratch/dx2/hc7988/anemoi-output/plots/7ac826b0a4c343d5980957a87093330b
# [2026-04-14 17:13:03,703][anemoi.training.train.train][INFO] - Dry run: False
# [2026-04-14 17:13:03,705][anemoi.training.data.datamodule][INFO] - Initializing multi-dataset module with datasets: ['data']
# [2026-04-14 17:13:03,711][anemoi.training.data.datamodule][WARNING] - Falling back rollout to: 1
# [2026-04-14 17:13:03,711][anemoi.training.data.dataset][INFO] - Creating NativeGridDataset...
# [2026-04-14 17:13:03,822][anemoi.utils.config][INFO] - Using environment variable ANEMOI_CONFIG_PATH to override the anemoi config key 'path.'
# [2026-04-14 17:13:04,147][anemoi.training.data.multidataset][INFO] - Timeincrement set to 1 for data with frequency, 21600, and timestep, 21600
# [2026-04-14 17:13:04,156][anemoi.training.data.multidataset][INFO] - Dataset 'data' has 16070 valid indices
# [2026-04-14 17:13:04,157][anemoi.training.data.multidataset][INFO] - MultiDataset has 16070 valid indices after intersection.
# [2026-04-14 17:13:04,157][anemoi.training.data.multidataset][INFO] - MultiDataset initialized with 1 datasets (data), 16070 valid indices each
# [2026-04-14 17:13:04,158][anemoi.training.train.train][INFO] - Dataset 'data' - Number of variables: 23
# [2026-04-14 17:13:04,158][anemoi.training.train.train][INFO] - Dataset 'data' - Variables: ['z_1000', 'z_500', 'z_700', 'z_300', '2t', 't_850', 'tcw', 'z_250', 'cp', 'tp', 'cos_latitude', 'cos_longitude', 'sin_latitude', 'sin_longitude', 'cos_julian_day', 'cos_local_time', 'sin_julian_day', 'sin_local_time', 'insolation', 'lsm', 'sdor', 'slor', 'z']
# [2026-04-14 17:13:04,261][anemoi.training.train.train][INFO] - Dataset 'data' - Total number of prognostic variables: 10
# [2026-04-14 17:13:04,261][anemoi.training.train.train][INFO] - Dataset 'data' - Total number of auxiliary variables: 13
# [2026-04-14 17:13:04,261][anemoi.training.train.train][INFO] - Total GPU count / model group size: 1 - NB: the learning rate will be scaled by this factor!
# [2026-04-14 17:13:04,262][anemoi.training.train.train][INFO] - Effective learning rate: 1.000e-03
# [2026-04-14 17:13:15,844][anemoi.training.diagnostics.callbacks.plot][INFO] - Setting up asynchronous plotting ...
# [2026-04-14 17:13:15,867][anemoi.training.diagnostics.callbacks][INFO] - Using progress bar: <class 'pytorch_lightning.callbacks.progress.tqdm_progress.TQDMProgressBar'>
# [2026-04-14 17:13:16,069][anemoi.models.migrations.migrator][INFO] - Loading migration 1755530253_initial
# [2026-04-14 17:13:16,069][anemoi.models.migrations.migrator][INFO] - Loading migration 1762857427_deprecate_eda
# [2026-04-14 17:13:16,070][anemoi.models.migrations.migrator][INFO] - Loading migration 1762857428_chunking_fix
# [2026-04-14 17:13:16,070][anemoi.models.migrations.migrator][INFO] - Loading migration 1763479917_hardware_schema_update
# [2026-04-14 17:13:16,070][anemoi.models.migrations.migrator][INFO] - Loading migration 1763479918_refactor_mapper
# [2026-04-14 17:13:16,070][anemoi.models.migrations.migrator][INFO] - Loading migration 1767108147_move_to_multiple_datasets
# [2026-04-14 17:13:16,070][anemoi.models.migrations.migrator][INFO] - Loading migration 1773048851_fuse_multiple_perdataset_graphs
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/pytorch_lightning/trainer/connectors/accelerator_connector.py:479: You passed `Trainer(accelerator='cpu', precision='16-mixed')` but AMP with fp16 is not supported on CPU. Using `precision='bf16-mixed'` instead.
# [2026-04-14 17:13:16,247][pytorch_lightning.utilities.rank_zero][INFO] - Using bfloat16 Automatic Mixed Precision (AMP)
# [2026-04-14 17:13:16,542][pytorch_lightning.utilities.rank_zero][INFO] - GPU available: False, used: False
# [2026-04-14 17:13:16,542][pytorch_lightning.utilities.rank_zero][INFO] - TPU available: False, using: 0 TPU cores
# [2026-04-14 17:13:16,593][pytorch_lightning.utilities.rank_zero][INFO] - 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# [2026-04-14 17:13:32,362][anemoi.graphs.nodes.builders.from_file][INFO] - Reading the dataset from {'dataset': '/g/data/dk92/data/aifs-ens/aifs-ea-an-oper-0001-mars-o48-2010-2022-6h-v1-toy.zarr', 'frequency': '6h', 'drop': [], 'select': ['z_1000', 'z_500', 'z_700', 'z_300', '2t', 't_850', 'tcw', 'z_250', 'lsm', 'z', 'cp', 'tp', 'cos_latitude', 'cos_longitude', 'sin_latitude', 'sin_longitude', 'cos_julian_day', 'cos_local_time', 'sin_julian_day', 'sin_local_time', 'insolation', 'lsm', 'sdor', 'slor', 'z']}.
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [2026-04-14 17:13:38,599][anemoi.graphs.edges.builders.cutoff][INFO] - Using CutOff-Edges (with radius = 144.6 km [factor=0.60]) between data and hidden.
# [2026-04-14 17:13:40,494][anemoi.graphs.edges.builders.base][WARNING] - The 'torch-cluster' library is not installed.
# Installing 'torch-cluster' can significantly improve performance for graph creation.
# You can install it using:
#     TORCH_VERSION=$(python -c "import torch; print(torch.__version__)")
#     pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH_VERSION}.html
#
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [2026-04-14 17:13:49,779][anemoi.graphs.edges.builders.knn][INFO] - Using KNN-Edges (with 3 nearest neighbours) between hidden and data.
# [2026-04-14 17:13:50,164][anemoi.graphs.edges.builders.base][WARNING] - The 'torch-cluster' library is not installed.
# Installing 'torch-cluster' can significantly improve performance for graph creation.
# You can install it using:
#     TORCH_VERSION=$(python -c "import torch; print(torch.__version__)")
#     pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH_VERSION}.html
#
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# [2026-04-14 17:13:55,105][anemoi.graphs.create][INFO] - Cleaning graph.
# [2026-04-14 17:13:55,107][anemoi.graphs.create][INFO] - _grid_reference_distance deleted from graph.
# [2026-04-14 17:13:55,108][anemoi.graphs.create][INFO] - _dataset deleted from graph.
# [2026-04-14 17:13:55,108][anemoi.graphs.create][INFO] - _grid_reference_distance deleted from graph.
# [2026-04-14 17:13:55,108][anemoi.graphs.create][WARNING] - No output path specified. The graph will not be saved.
# [2026-04-14 17:13:55,108][lightning_fabric.utilities.seed][INFO] - Seed set to 42000
# [2026-04-14 17:13:55,491][anemoi.training.train.train][INFO] - Initial seed: Rank 0, initial seed 42000, running with random seed: 42000
# [2026-04-14 17:14:14,909][anemoi.training.data.datamodule][WARNING] - Falling back rollout to: 1
# [2026-04-14 17:14:15,646][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_latitude is not normalized.
# [2026-04-14 17:14:15,647][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_longitude is not normalized.
# [2026-04-14 17:14:15,647][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_latitude is not normalized.
# [2026-04-14 17:14:15,647][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_longitude is not normalized.
# [2026-04-14 17:14:15,647][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_julian_day is not normalized.
# [2026-04-14 17:14:15,647][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_local_time is not normalized.
# [2026-04-14 17:14:15,647][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_julian_day is not normalized.
# [2026-04-14 17:14:15,647][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_local_time is not normalized.
# [2026-04-14 17:14:15,647][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: insolation is not normalized.
# [2026-04-14 17:14:15,647][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: lsm is not normalized.
# [2026-04-14 17:14:15,683][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_latitude is not normalized.
# [2026-04-14 17:14:15,683][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_longitude is not normalized.
# [2026-04-14 17:14:15,683][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_latitude is not normalized.
# [2026-04-14 17:14:15,683][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_longitude is not normalized.
# [2026-04-14 17:14:15,683][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_julian_day is not normalized.
# [2026-04-14 17:14:15,684][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_local_time is not normalized.
# [2026-04-14 17:14:15,684][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_julian_day is not normalized.
# [2026-04-14 17:14:15,684][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_local_time is not normalized.
# [2026-04-14 17:14:15,684][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: insolation is not normalized.
# [2026-04-14 17:14:15,684][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: lsm is not normalized.
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/anemoi/models/preprocessing/normalizer.py:95: RuntimeWarning: divide by zero encountered in scalar divide
#   _norm_mul[i] = 1 / maximum[i]
# [2026-04-14 17:14:16,520][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-14 17:14:16,522][anemoi.models.layers.utils][INFO] - LayerNorm kernel: torch.nn.LayerNorm.
# [2026-04-14 17:14:16,523][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-14 17:14:16,544][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-14 17:14:16,547][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-14 17:14:16,706][anemoi.models.layers.block][WARNING] - GraphTransformerMapperBlock requested the triton graph attention backend but triton is not available. Falling back to 'pyg' backend.
# [2026-04-14 17:14:16,849][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-14 17:14:16,852][anemoi.models.layers.utils][INFO] - LayerNorm kernel: anemoi.models.layers.normalization.ConditionalLayerNorm.
# [2026-04-14 17:14:16,854][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-14 17:14:16,856][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-14 17:14:16,859][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-14 17:14:16,860][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-14 17:14:16,928][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-14 17:14:16,934][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-14 17:14:16,938][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-14 17:14:16,943][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-14 17:14:16,946][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-14 17:14:16,949][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-14 17:14:16,952][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-14 17:14:17,014][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-14 17:14:17,016][anemoi.models.layers.utils][INFO] - LayerNorm kernel: torch.nn.LayerNorm.
# [2026-04-14 17:14:17,017][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-14 17:14:17,018][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-14 17:14:17,019][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-14 17:14:17,101][anemoi.models.layers.block][WARNING] - GraphTransformerMapperBlock requested the triton graph attention backend but triton is not available. Falling back to 'pyg' backend.
# [2026-04-14 17:14:17,130][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-14 17:14:17,132][anemoi.models.layers.utils][INFO] - LayerNorm kernel: torch.nn.LayerNorm.
# [2026-04-14 17:14:17,134][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-14 17:14:17,136][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-14 17:14:17,138][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-14 17:14:17,139][anemoi.models.layers.ensemble][INFO] - processor noise channels = 4
# [2026-04-14 17:14:17,410][anemoi.training.losses.scalers.variable_level][INFO] - Variable Level Scaling: Applying ReluVariableLevelScaler scaling to pl variables ({'param': ['q', 't', 'u', 'v', 'w', 'z']})
# [2026-04-14 17:14:17,410][anemoi.training.losses.scalers.variable_level][INFO] - with slope = 0.001 and y-intercept/minimum = 0.2.
# [2026-04-14 17:14:17,625][anemoi.training.losses.multiscale][INFO] - Loss smoothing: None
# [2026-04-14 17:14:17,634][anemoi.training.losses.multiscale][INFO] - Loss smoothing: None
# [2026-04-14 17:14:17,661][anemoi.training.train.tasks.base][INFO] - GraphModule with n_step_input=2 and n_step_output=1
# [2026-04-14 17:14:17,663][anemoi.training.train.tasks.ensforecaster][INFO] - Base (config) learning rate: 1.000000e-03 -- Effective learning rate: 1.000000e-03
# [2026-04-14 17:14:17,663][anemoi.training.train.tasks.ensforecaster][INFO] - Ensemble size: per device = 2, per ens-group = 2
# [2026-04-14 17:14:17,663][anemoi.training.train.train][INFO] - The following submodules will NOT be trained: []
# [2026-04-14 17:14:17,702][anemoi.models.utils.compile][INFO] - The following modules will be compiled: []
# [2026-04-14 17:14:17,702][anemoi.training.train.train][INFO] - Recompile limit set to 32
# [2026-04-14 17:14:17,890][lightning_fabric.utilities.distributed][INFO] - Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [2026-04-14 17:14:18,177][pytorch_lightning.utilities.rank_zero][INFO] - ----------------------------------------------------------------------------------------------------
# distributed_backend=gloo
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# [2026-04-14 17:14:18,285][anemoi.training.diagnostics.mlflow.logger][INFO] - Logging 12 parameters
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [2026-04-14 17:14:18,372][anemoi.training.distributed.strategy][INFO] - Rank 0 model_comm_group_id: 0 model_comm_group: [0] model_comm_group_rank: 0 model_comm_group.size(): 1 reader_group_id: 0 reader_group: [0] reader_group_rank: 0 reader_group_root (global): 0 model_reader_groups: [<torch.distributed.distributed_c10d.ProcessGroup object at 0x7fec59169030>] reader_groups: [[<torch.distributed.distributed_c10d.ProcessGroup object at 0x7fec59169030>]]
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [Gloo] Rank 0 is connected to 0 peer ranks. Expected number of connected peer ranks is : 0
# [2026-04-14 17:14:18,376][anemoi.training.distributed.strategy][INFO] - Rank 0 ens_comm_group_id: 0 ens_comm_group: [0] ens_comm_group_rank: 0 ens_comm_group_size: 1 ens_comm_group.size(): 1 ens_comm_subgroup_id: 0 ens_comm_subgroup: [0] ens_comm_subgroup_rank: 0 ens_comm_subgroup.size(): 1
# [2026-04-14 17:14:18,602][anemoi.training.train.tasks.base][INFO] - Optimizer initialized: AdamW
# [2026-04-14 17:14:18,602][anemoi.training.train.tasks.base][INFO] - Optimizer settings: {'lr': 0.001, 'betas': [0.9, 0.95], 'eps': 1e-08, 'weight_decay': 0.01, 'amsgrad': False, 'maximize': False, 'foreach': None, 'capturable': False, 'differentiable': False, 'fused': None, 'decoupled_weight_decay': True}
# [2026-04-14 17:14:18,885][lightning_fabric.utilities.seed][INFO] - [rank: 0] Seed set to 42000
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision bf16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name    ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model   │ AnemoiModelInterface │  2.6 M │ train │     0 │
# │ 1 │ loss    │ ModuleDict           │      0 │ train │     0 │
# │ 2 │ metrics │ ModuleDict           │      0 │ train │     0 │
# └───┴─────────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 2.6 M
# Non-trainable params: 0
# Total params: 2.6 M
# Total estimated model params size (MB): 10
# Modules in train mode: 272
# Modules in eval mode: 0
# Total FLOPs: 0
# [2026-04-14 17:14:19,045][anemoi.training.diagnostics.mlflow.logger][INFO] - Logging 620 parameters
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s][2026-04-14 17:14:20,472][anemoi.training.data.datamodule][WARNING] - Falling back rollout to: 1
# [2026-04-14 17:14:20,473][anemoi.training.data.dataset][INFO] - Creating NativeGridDataset...
# [2026-04-14 17:14:20,670][anemoi.training.data.multidataset][INFO] - Timeincrement set to 1 for data with frequency, 21600, and timestep, 21600
# [2026-04-14 17:14:20,682][anemoi.training.data.multidataset][INFO] - Dataset 'data' has 1458 valid indices
# [2026-04-14 17:14:20,682][anemoi.training.data.multidataset][INFO] - MultiDataset has 1458 valid indices after intersection.
# [2026-04-14 17:14:20,682][anemoi.training.data.multidataset][INFO] - MultiDataset initialized with 1 datasets (data), 1458 valid indices each
# [2026-04-14 17:14:20,695][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_group_info(): global_rank 0, model_comm_group_id 0, model_comm_group_rank 0, model_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# [2026-04-14 17:14:20,696][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_ens_comm_group_info(): global_rank 0, ens_comm_group_id 0, ens_comm_group_rank 0, ens_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# [2026-04-14 17:14:21,025][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
# [2026-04-14 17:14:21,026][anemoi.training.data.multidataset][INFO] - Worker 6 (pid 202081, global_rank 0, model comm group 0)  has low/high range 1094 / 1276
# [2026-04-14 17:14:21,026][anemoi.training.data.multidataset][INFO] - Worker 0 (pid 202056, global_rank 0, model comm group 0)  has low/high range 0 / 183
# [2026-04-14 17:14:21,026][anemoi.training.data.multidataset][INFO] - Worker 2 (pid 202072, global_rank 0, model comm group 0)  has low/high range 366 / 548
# [2026-04-14 17:14:21,026][anemoi.training.data.multidataset][INFO] - Worker 4 (pid 202076, global_rank 0, model comm group 0)  has low/high range 730 / 912
# [2026-04-14 17:14:21,026][anemoi.training.data.multidataset][INFO] - Worker 3 (pid 202073, global_rank 0, model comm group 0)  has low/high range 548 / 730
# [2026-04-14 17:14:21,026][anemoi.training.data.multidataset][INFO] - Worker 5 (pid 202077, global_rank 0, model comm group 0)  has low/high range 912 / 1094
# [2026-04-14 17:14:21,026][anemoi.training.data.multidataset][INFO] - Worker 1 (pid 202066, global_rank 0, model comm group 0)  has low/high range 183 / 366
# [2026-04-14 17:14:21,028][anemoi.training.data.multidataset][INFO] - Worker 7 (pid 202086, global_rank 0, model comm group 0)  has low/high range 1276 / 1458
# [2026-04-14 17:14:21,081][anemoi.training.data.multidataset][INFO] - Worker 3 (validation, pid 202073, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:14:21,081][anemoi.training.data.multidataset][INFO] - Worker 5 (validation, pid 202077, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:14:21,081][anemoi.training.data.multidataset][INFO] - Worker 2 (validation, pid 202072, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:14:21,081][anemoi.training.data.multidataset][INFO] - Worker 1 (validation, pid 202066, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:14:21,081][anemoi.training.data.multidataset][INFO] - Worker 4 (validation, pid 202076, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:14:21,081][anemoi.training.data.multidataset][INFO] - Worker 7 (validation, pid 202086, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:14:21,081][anemoi.training.data.multidataset][INFO] - Worker 6 (validation, pid 202081, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:14:21,081][anemoi.training.data.multidataset][INFO] - Worker 0 (validation, pid 202056, base_seed 42000, sanity rnd 0.315034)
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:378: You have overridden `transfer_batch_to_device` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:378: You have overridden `on_after_batch_transfer` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:  17%|█▋        | 1/6 [01:44<08:42,  0.01it/s]
# Sanity Checking DataLoader 0:  33%|███▎      | 2/6 [02:46<05:33,  0.01it/s]
# Sanity Checking DataLoader 0:  50%|█████     | 3/6 [03:43<03:43,  0.01it/s]
# Sanity Checking DataLoader 0:  67%|██████▋   | 4/6 [04:38<02:19,  0.01it/s]
# Sanity Checking DataLoader 0:  83%|████████▎ | 5/6 [05:34<01:06,  0.01it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 6/6 [06:37<00:00,  0.02it/s]
#
# [2026-04-14 17:20:59,093][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_group_info(): global_rank 0, model_comm_group_id 0, model_comm_group_rank 0, model_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# [2026-04-14 17:20:59,109][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_ens_comm_group_info(): global_rank 0, ens_comm_group_id 0, ens_comm_group_rank 0, ens_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/torch/cuda/__init__.py:827: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib64/python3.12/site-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# [2026-04-14 17:20:59,586][anemoi.training.data.multidataset][INFO] - Worker 2 (pid 252364, global_rank 0, model comm group 0)  has low/high range 4018 / 6027
# [2026-04-14 17:20:59,594][anemoi.training.data.multidataset][INFO] - Worker 3 (pid 252365, global_rank 0, model comm group 0)  has low/high range 6027 / 8036
# [2026-04-14 17:20:59,597][anemoi.training.data.multidataset][INFO] - Worker 0 (pid 252359, global_rank 0, model comm group 0)  has low/high range 0 / 2009
# [2026-04-14 17:20:59,597][anemoi.training.data.multidataset][INFO] - Worker 1 (pid 252360, global_rank 0, model comm group 0)  has low/high range 2009 / 4018
# [2026-04-14 17:20:59,608][anemoi.training.data.multidataset][INFO] - Worker 0 (training, pid 252359, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:20:59,608][anemoi.training.data.multidataset][INFO] - Worker 3 (training, pid 252365, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:20:59,608][anemoi.training.data.multidataset][INFO] - Worker 1 (training, pid 252360, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:20:59,608][anemoi.training.data.multidataset][INFO] - Worker 2 (training, pid 252364, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:20:59,624][anemoi.training.data.multidataset][INFO] - Worker 4 (pid 252366, global_rank 0, model comm group 0)  has low/high range 8036 / 10045
# [2026-04-14 17:20:59,626][anemoi.training.data.multidataset][INFO] - Worker 4 (training, pid 252366, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:20:59,665][anemoi.training.data.multidataset][INFO] - Worker 5 (pid 252368, global_rank 0, model comm group 0)  has low/high range 10045 / 12054
# [2026-04-14 17:20:59,669][anemoi.training.data.multidataset][INFO] - Worker 5 (training, pid 252368, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:20:59,701][anemoi.training.data.multidataset][INFO] - Worker 6 (pid 252374, global_rank 0, model comm group 0)  has low/high range 12054 / 14062
# [2026-04-14 17:20:59,704][anemoi.training.data.multidataset][INFO] - Worker 6 (training, pid 252374, base_seed 42000, sanity rnd 0.315034)
# [2026-04-14 17:20:59,737][anemoi.training.data.multidataset][INFO] - Worker 7 (pid 252375, global_rank 0, model comm group 0)  has low/high range 14062 / 16070
# [2026-04-14 17:20:59,739][anemoi.training.data.multidataset][INFO] - Worker 7 (training, pid 252375, base_seed 42000, sanity rnd 0.315034)
#
# Training: |          | 0/? [00:00<?, ?it/s][2026-04-14 17:20:59,761][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 0:   5%|▌         | 1/20 [08:56<2:49:56,  0.00it/s]

# %% [markdown]
# ## Monitoring and Results
#
# ### MLflow logging
#
# Several metrics and parameters are logged during training. Here, we use MLflow to log results offline.
#
# In the following we use the MLflow API to plot some key metrics during training, such as:
#
# - **Training Loss**: The AlmostFairKernelCRPS loss should decrease over time
# - **Validation Metrics**: Similar to training loss, calculated on validation data
#
# *Note:* Typically the logging is done to a server and can be used interactively on a website.

# %% [markdown]
# ## Server logging
#
# Mlflow logs can be viewed in a web interface, below we skip this and directly retrieve, but if you want to do see it in that ui, move to the logging directory within this environment, and run `mlflow server`
#
# ```bash
# cd /scratch/$PROJECT/$USER/anemoi-outputs/logs/mlflow
# mlflow server
# ```

# %%
import mlflow
import pandas as pd
import matplotlib.pyplot as plt

run_id="01c343369d05474b9c9f10fa6687843b" # CHANGE THIS TO YOUR RUN ID

# Start mlflow client and load run
client = mlflow.tracking.MlflowClient(tracking_uri=f"file:///scratch/{os.getenv('PROJECT')}/{os.getenv('USER')}/anemoi-output/logs/mlflow")
run = client.get_run(run_id)

print(f"Run name: {run.info.run_name}")
print("Logged metrics:")
print("=" * 50)
for k in run.data.metrics.keys():
    print(k)
# Out:
#   Cell In[9], line 8
#     client = mlflow.tracking.MlflowClient(tracking_uri=f"file:///scratch/{os.getenv("PROJECT")}/{os.getenv("USER")}/anemoi-output/logs/mlflow")
#                                                                                      ^
# SyntaxError: f-string: unmatched '('

# %%
# Plotting,
metric_names = ['train_multi_dataset_loss_step', 'val_multi_dataset_loss_epoch']

# Load data into DataFrame
data = []
for metric in metric_names:
    for entry in client.get_metric_history(run_id, metric):
        data.append({'metric': metric, 'step': entry.step, 'value': entry.value, 'time': entry.timestamp})
df = pd.DataFrame(data)

# Plot all metrics
fig, ax = plt.subplots()
for metric in df['metric'].unique():
    metric_data = df[df['metric'] == metric].sort_values('step')
    ax.plot(metric_data['step'], metric_data['value'], '-o', label=metric)
ax.legend()
ax.set_xlabel('steps')
ax.set_ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### Task 1: Change the number of ensemble members
#
# Adapt the training config and retrain the model with:
#    - a larger number of ensemble members, e.g. `ensemble_size_per_device=4`
#    - train the model for longer by increasing the number of iterations (`max_steps`) and removing the batch limit
#
# **Questions**
# - How does your loss change with the same number of steps?
# - How much longer does the training take per iteration?
# - What happens if you choose a large number of ensemble members?
#
# ***Note***:
#
# You do not need to do the training in the notebook. You can run on the console with:
# ```
# anemoi-training train --config-path PATH-TO-YOUR-CONFIG-FOLDER --config-name aifs_ens_minimal_config
# ```
#
# #### Task 1.1: Alter the config
#
# Throughout the top level config, are various `ACTIVITY:` prompts which show parts you can easily modify to alter the training behaviour, explore these and design an experiment.

# %% [markdown]
# ### (Optional) Task 2: Inference of your model
#
# Run inference on the model you have trained. For that, go back to the Jupyter notebook `../4-run-AIFS/inference_aifs-ens.ipynb` and import your used checkpoint.
#
# ***Note:***
#
# You need to adapt,
# 1. The resolution of the data for your input fields to O48
#
# ```
# GRID_RESOLUTION = "O48"
# PARAM_SFC = ["2t", 'z', 'lsm', "tcw", "sdor", "slor"]
# PARAM_PL = ["gh", "t"]
# LEVELS = [1000, 850, 700, 500, 300, 250]
# ```
#
# 2. Select only the input fields you need, i.e. ['z_1000', 'z_500', 'z_700', 'z_300', '2t', 't_850', 'tcw', 'z_250', 'lsm', 'z', 'sdor', 'slor']
#
#
# In case you were not able to train the checkpoint. You can find a checkpoint here:
# PUT_GADI_CHECKPOINT_LOCATION_HERE
