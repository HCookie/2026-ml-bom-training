# %%
import nci_ipynb
import os
nb_path = nci_ipynb.dir()
os.chdir(nb_path)

# %% [markdown]
# # Hands-on: Training an AIFS-ENS with Anemoi
#
# In this tutorial we will learn how to train a model like the AIFS-ENS (ensemble) model using the anemoi packages. We'll focus on the CRPS (Continuous Ranked Probability Score) based training approach, which is specifically designed for ensemble weather forecasting.
#
# **Learning Objectives**
#
# By the end of this tutorial, you will:
# - Understand the key differences between deterministic and ensemble CRPS training
# - Learn how to configure the anemoi training pipeline for ensemble models
# - Build a minimal training configuration step-by-step
# - Execute a short training run to verify everything works
#
#
# **Resources**
#
# - [Anemoi docu: CRPS-based training](https://anemoi.readthedocs.io/projects/training/en/latest/user-guide/kcrps-set-up.html)
# - [Anemoi Documentation](https://anemoi.readthedocs.io/projects/training/en/latest/)
# - [Lang et al. 2024](http://arxiv.org/abs/2412.15832)

# %% [markdown]
# ## Background: What is CRPS Training?
#
# The **Continuous Ranked Probability Score (CRPS)** is a proper scoring rule for evaluating probabilistic forecasts. In the context of ensemble weather forecasting, CRPS training allows us to train models that produce multiple ensemble members, each representing a different possible future state of the atmosphere.
#
# <img src="_resources/aifs-crps_sketch.png" alt="CRPS Sketch" width="900">
#
# ### Why Ensemble Training?
#
# - **Uncertainty Quantification**: Each ensemble member represents a different possible future
# - **Probabilistic Forecasting**: Provides uncertainty estimates alongside predictions
# - **Better Skill Scores**: Often outperforms deterministic models in terms of skill metrics
# - **Operational Use**: Essential for weather services that need to communicate forecast uncertainty

# %% [markdown]
# ## CRPS Training in Anemoi
#
# ### Key Differences: Deterministic vs CRPS Training
#
# The main components of the training pipeline need to be modified when switching from deterministic to ensemble CRPS training:
#
# | Component | Deterministic | CRPS |
# |-----------|---------------|------|
# | **Forecaster** | `GraphForecaster` | `GraphEnsForecaster` |
# | **Strategy** | `DDPGroupStrategy` | `DDPEnsGroupStrategy` |
# | **Training Loss** | `WeightedMSELoss` | `AlmostFairKernelCRPS` |
# | **Model** | `AnemoiModelEncProcDec` | `AnemoiEnsModelEncProcDec` |
# | **Datamodule** | `AnemoiDatasetsDataModule` | `AnemoiEnsDatasetsDataModule` |
#
#
# #### The AlmostFairKernelCRPS Loss
#
# The training uses the AlmostFairKernelCRPS loss function, which combines the traditional CRPS with a "fair" version:
#
# $$\text{afCRPS}_\alpha := \alpha\text{fCRPS} + (1-\alpha)\text{CRPS}$$
#
# Where $\alpha$ is a trade-off parameter between the CRPS and the fair CRPS.

# %% [markdown]
# ## Building Our Training Config
#
# Now we'll examine our training configuration step-by-step, highlighting the key differences from deterministic training. We have a minimal configuration file ready that we'll load and examine section by section.

# %%
# Let's start by importing the necessary modules
import yaml
from omegaconf import OmegaConf
from pathlib import Path

# Load our minimal configuration file
config_path = nb_path / Path("configs/aifs_ens_minimal.yaml")
with open(config_path, 'r') as f:
    config = yaml.safe_load(f)

# %% [markdown]
# ### Step 1: Hardware Configuration
#
# The hardware configuration needs to specify the number of GPUs per ensemble, which is crucial for the ensemble training strategy.
#
# **Key Points:**
# - `num_gpus_per_ensemble`: Number of GPUs to use per ensemble (typically 1 for small setups)
# - `num_gpus_per_model`: Number of GPUs per model instance
# - Total ensemble members = `ensemble_size_per_device` × `num_gpus_per_ensemble` (we'll set this later)

# %%
# Display the system configuration section
print("System Configuration:")
print("=" * 50)
print(yaml.dump(config['system'], default_flow_style=False))
# Out:
# System Configuration:
# ==================================================
# hardware:
#   accelerator: auto
#   num_gpus_per_ensemble: 1
#   num_gpus_per_model: 1
# input:
#   dataset: /g/data/dk92/data/aifs-ens/aifs-ea-an-oper-0001-mars-o48-2010-2022-6h-v1-toy.zarr
#   graph: null
# output:
#   root: /scratch/${oc.env:PROJECT}/${oc.env:USER}/anemoi-output/

# %% [markdown]
# ### Step 2: Model Configuration
#
# Key model changes for CRPS-based training are:
#
# 1. **Ensemble Model Class**: Uses `AnemoiEnsModelEncProcDec` instead of `AnemoiModelEncProcDec`
#
# 2. **Noise Injector**: Each ensemble member samples random noise at every time step:
#    ```yaml
#    noise_injector:
#      _target_: anemoi.models.layers.ensemble.NoiseConditioning
#      noise_std: 1
#      noise_channels_dim: 4
#      noise_mlp_hidden_dim: 32
#    ```
#
# 3. **Conditional Layer Normalization**: The processor uses `ConditionalLayerNorm` instead of regular `LayerNorm` to condition the latent space on the noise:
#    ```yaml
#    processor:
#      layer_kernels:
#        LayerNorm:
#          _target_: anemoi.models.layers.normalization.ConditionalLayerNorm
#          normalized_shape: ${model.num_channels}
#          condition_shape: ${model.noise_injector.noise_channels_dim}
#    ```
#
#    Unlike standard layer normalization that normalizes features independently, conditional layer normalization allows the normalization to be conditioned on additional information (in this case, noise vectors).
#     - Each ensemble member gets a unique noise vector at every time step
#     - This noise is embedded and used to condition the layer normalization in the processor
#     - The conditioning allows the same model weights to produce different outputs for different ensemble members
#     - This creates diversity in the ensemble predictions while sharing computational resources
#
#
# This noise injection and conditioning is what allows each ensemble member to produce different predictions while sharing the same model weights.

# %%
# Display the model configuration section
print("Model Configuration:")
print("=" * 30)
print(yaml.dump(config['model'], default_flow_style=False))
# Out:
# Model Configuration:
# ==============================
# compile: []
# condition_on_residual: false
# decoder:
#   graph_attention_backend: pyg
# encoder:
#   graph_attention_backend: pyg
# model:
#   _target_: anemoi.models.models.AnemoiEnsModelEncProcDec
# noise_injector:
#   _target_: anemoi.models.layers.ensemble.NoiseConditioning
#   layer_kernels:
#     Activation:
#       _target_: torch.nn.GELU
#   noise_channels_dim: 4
#   noise_mlp_hidden_dim: 32
#   noise_std: 1
# num_channels: 128
# processor:
#   _target_: anemoi.models.layers.processor.TransformerProcessor
#   attention_implementation: scaled_dot_product_attention
#   layer_kernels:
#     LayerNorm:
#       _target_: anemoi.models.layers.normalization.ConditionalLayerNorm
#       autocast: false
#       condition_shape: ${model.noise_injector.noise_channels_dim}
#       normalized_shape: ${model.num_channels}
#   mlp_hidden_ratio: 4
#   num_chunks: 4
#   num_heads: 16
#   num_layers: 8
#   window_size: 512

# %% [markdown]
# ## Step 3: Data configuraation
#
# Now we configure the dataset, and loading parameters.
#
# **Key Data Parameters:**
#
# 1. **batch_size**: Control how many batches are seen
# 2. **training.datasets**: Use anemoi-datasets to open and select the training data

# %%
# Display the model configuration section
print("Dataloader Configuration:")
print("=" * 30)
print(yaml.dump(config['dataloader'], default_flow_style=False))
# Out:
# Dataloader Configuration:
# ==============================
# batch_size:
#   training: 1
#   validation: 1
# limit_batches:
#   training: 20
#   validation: 50
# training:
#   datasets:
#     data:
#       dataset_config:
#         dataset: ${dataloader.dataset}
#         select:
#         - z_1000
#         - z_500
#         - z_700
#         - z_300
#         - 2t
#         - t_850
#         - tcw
#         - z_250
#         - lsm
#         - z
#         - cp
#         - tp
#         - cos_latitude
#         - cos_longitude
#         - sin_latitude
#         - sin_longitude
#         - cos_julian_day
#         - cos_local_time
#         - sin_julian_day
#         - sin_local_time
#         - insolation
#         - lsm
#         - sdor
#         - slor
#         - z
#       end: 2020
#       start: null
# validation:
#   datasets:
#     data:
#       dataset_config: ${dataloader.training.datasets.data.dataset_config}
#       end: 2021
#       start: 2021

# %% [markdown]
# ### Step 4: Training Configuration
#
# Now we configure the training parameters, strategy, and loss function for ensemble training.
#
# **Key Training Parameters:**
#
# 1. **Model Task**: Set to `GraphEnsForecaster` (handled by the `ensemble` training default)
# 2. **Ensemble Size**: `ensemble_size_per_device: 2` means 2 ensemble members per device. Thus, the **Total Ensemble Members** is:
#     ```
#    ensemble_size_per_device × num_nodes x num_gpus_per_node / ( num_gpus_per_member x num_gpus_per_mod) = 2 × 1 x 1 / (1 x 1) = 2 members
#    ```
#
# 3. **Strategy**: Uses `DDPEnsGroupStrategy` (handled by the `ensemble` training default)
# 4. **Loss Function**: `AlmostFairKernelCRPS` with `alpha=1.0` (pure fair CRPS)

# %%
# Display the training configuration section
print("Training Configuration:")
print("=" * 30)
print(yaml.dump(config['training'], default_flow_style=False))
# Out:
# Training Configuration:
# ==============================
# ensemble_size_per_device: 2
# lr:
#   iterations: ${training.max_steps}
#   min: 3e-7
#   rate: 1e-3
#   warmup: 1000
# max_steps: 1000
# model_task: anemoi.training.train.tasks.GraphEnsForecaster
# strategy:
#   _target_: anemoi.training.distributed.strategy.DDPEnsGroupStrategy
#   num_gpus_per_ensemble: ${system.hardware.num_gpus_per_ensemble}
#   num_gpus_per_model: ${system.hardware.num_gpus_per_model}
#   read_group_size: ${dataloader.read_group_size}
# training_loss:
#   datasets:
#     data:
#       _target_: anemoi.training.losses.MultiscaleLossWrapper
#       keep_batch_sharded: ${model.keep_batch_sharded}
#       loss_matrices:
#       - null
#       loss_matrices_path: ${system.input.loss_matrices_path}
#       per_scale_loss:
#         _target_: anemoi.training.losses.kcrps.AlmostFairKernelCRPS
#         alpha: 0.95
#         ignore_nans: false
#         no_autocast: true
#         scalers:
#         - pressure_level
#         - general_variable
#         - nan_mask_weights
#         - node_weights
#         - time_steps
#       weights:
#       - 1.0
# validation_metrics:
#   datasets:
#     data:
#       fkcrps:
#         _target_: anemoi.training.losses.kcrps.AlmostFairKernelCRPS
#         alpha: 1.0
#         ignore_nans: false
#         scalers:
#         - node_weights
#         - time_steps
#       multiscale:
#         _target_: anemoi.training.losses.MultiscaleLossWrapper
#         keep_batch_sharded: ${model.keep_batch_sharded}
#         loss_matrices:
#         - null
#         loss_matrices_path: ${system.input.loss_matrices_path}
#         per_scale_loss:
#           _target_: anemoi.training.losses.kcrps.AlmostFairKernelCRPS
#           alpha: 1.0
#           ignore_nans: false
#           no_autocast: true
#           scalers:
#           - node_weights
#           - time_steps
#         weights:
#         - 1.0

# %% [markdown]
# ## Training Execution
#
# Now that we have our configuration ready, let's execute the training. We'll run a short training session to verify everything works correctly by running,
#
# ```bash
# export ANEMOI_BASE_SEED=42
# export ANEMOI_CONFIG_PATH="$PWD/configs"
# anemoi-training train --config-name aifs_ens_minimal
# ```

# %%
import subprocess
import sys, os 

# Set environment variables
os.environ['ANEMOI_BASE_SEED'] = '42'

os.environ['PBS_NGPUS'] = '1' # Set to 1 for single GPU training, adjust if using multiple GPUs
os.environ['PBS_NNODES'] = '1' # Set to 1 for single node training, adjust if using multiple nodes

os.environ['ANEMOI_CONFIG_PATH'] = str(nb_path / "configs")
os.environ['POSSIBLE_USER_WARNINGS'] = 'off'
os.environ['TORCH_LOGS'] = "-dynamo,-inductor"

# Execute the training using subprocess
print("Starting AIFS-ENS training...")
print("=" * 50)

process = subprocess.Popen(
    [
        "anemoi-training", "train", 
        "--config-name", "aifs_ens_minimal.yaml"
    ], 
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,  # Merge stderr into stdout
    text=True,
    bufsize=1,  # Line buffered
    universal_newlines=True
)

# Stream output
for line in iter(process.stdout.readline, ''):
    if line:
        print(line.rstrip())  # Print immediately to Jupyter cell

# Wait for completion
return_code = process.wait()

print("=" * 50)
if return_code == 0:
    print("✓ Training completed successfully!")
else:
    print(f"❌ Training failed with return code {return_code}")
# Out:
# Starting AIFS-ENS training...
# ==================================================
# 2026-04-13 17:22:04 INFO Running anemoi training command with overrides: ['--config-name', 'aifs_ens_minimal.yaml']
# 2026-04-13 17:22:13 INFO Prepending Anemoi Config Env (/home/548/hc7988/.jupyter-root/home/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi/configs) to the search path.
# 2026-04-13 17:22:13 INFO Prepending current user directory (/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi) to the search path.
# 2026-04-13 17:22:13 INFO Search path is now: [provider=anemoi-cwd-searchpath-plugin, path=/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi, provider=anemoi-env-searchpath-plugin, path=/home/548/hc7988/.jupyter-root/home/Projects/ECMWF/training/2026-ml-bom-training/1-Anemoi/configs, provider=hydra, path=pkg://hydra.conf, provider=main, path=pkg://anemoi.training/config, provider=anemoi-package-searchpath-plugin, path=pkg://anemoi.training/config]
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib/python3.12/site-packages/torch/__init__.py:1617: UserWarning: Please use the new API settings to control TF32 behavior, such as torch.backends.cudnn.conv.fp32_precision = 'tf32' or torch.backends.cuda.matmul.fp32_precision = 'ieee'. Old settings, e.g, torch.backends.cuda.matmul.allow_tf32 = True, torch.backends.cudnn.allow_tf32 = True, allowTF32CuDNN() and allowTF32CuBLAS() will be deprecated after Pytorch 2.9. Please see https://pytorch.org/docs/main/notes/cuda.html#tensorfloat-32-tf32-on-ampere-and-later-devices (Triggered internally at /pytorch/aten/src/ATen/Context.cpp:80.)
#   _C._set_float32_matmul_precision(precision)
# [2026-04-13 17:22:14,376][anemoi.training.schemas.base_schema][INFO] - adjusting save_dir path to match output mlflow logs
# [2026-04-13 17:22:14,376][anemoi.training.train.train][INFO] - Skipping config validation.
# [2026-04-13 17:22:14,417][anemoi.training.train.train][INFO] - Starting from checkpoint: False
# [2026-04-13 17:22:14,417][anemoi.training.train.train][INFO] - MLFLOW logger enabled
# [2026-04-13 17:22:14,417][anemoi.training.train.train][INFO] - Initializing MLflow logger lazily...
# [2026-04-13 17:22:16,156][anemoi.training.diagnostics.mlflow.logger][INFO] - Maximum number of params allowed to be logged is: 2000
# [2026-04-13 17:22:16,162][anemoi.training.diagnostics.mlflow.logger][INFO] - MLflow is logging offline.
# [2026-04-13 17:22:16,176][root][WARNING] - Malformed experiment 'mlruns'. Detailed error Yaml file '/scratch/dx2/hc7988/anemoi-output/logs/mlflow/mlruns/meta.yaml' does not exist.
# Traceback (most recent call last):
#   File "/g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib/python3.12/site-packages/mlflow/store/tracking/file_store.py", line 347, in search_experiments
#     exp = self._get_experiment(exp_id, view_type)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib/python3.12/site-packages/mlflow/store/tracking/file_store.py", line 445, in _get_experiment
#     meta = FileStore._read_yaml(experiment_dir, FileStore.META_DATA_FILE_NAME)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib/python3.12/site-packages/mlflow/store/tracking/file_store.py", line 1588, in _read_yaml
#     return _read_helper(root, file_name, attempts_remaining=retries)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib/python3.12/site-packages/mlflow/store/tracking/file_store.py", line 1581, in _read_helper
#     result = read_yaml(root, file_name)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib/python3.12/site-packages/mlflow/utils/yaml_utils.py", line 107, in read_yaml
#     raise MissingConfigException(f"Yaml file '{file_path}' does not exist.")
# mlflow.exceptions.MissingConfigException: Yaml file '/scratch/dx2/hc7988/anemoi-output/logs/mlflow/mlruns/meta.yaml' does not exist.
# [2026-04-13 17:22:17,219][anemoi.training.diagnostics.mlflow.logger][INFO] - Terminal Log Path: /scratch/dx2/hc7988/anemoi-output/plots/01c343369d05474b9c9f10fa6687843b/plots/terminal_log.txt
# [2026-04-13 17:22:17,273][anemoi.training.diagnostics.mlflow.logger][WARNING] - Failed to init AMD GPU Monitor: `pyrsmi` is not installed, if you are running on an AMD GPU                 and want to log GPU metrics please run `pip install pyrsmi`.
# 2026/04/13 17:22:17 INFO mlflow.system_metrics.system_metrics_monitor: Started monitoring system metrics.
# [2026-04-13 17:22:17,275][anemoi.training.train.train][INFO] - Run id: 01c343369d05474b9c9f10fa6687843b
# [2026-04-13 17:22:17,276][anemoi.training.train.train][INFO] - Parent run server2server: None
# [2026-04-13 17:22:17,276][anemoi.training.train.train][INFO] - Fork run server2server: None
# [2026-04-13 17:22:17,277][anemoi.training.train.train][INFO] - Checkpoints path: {'root': PosixPath('/scratch/dx2/hc7988/anemoi-output/checkpoint/01c343369d05474b9c9f10fa6687843b'), 'every_n_epochs': 'anemoi-by_epoch-epoch_{epoch:03d}-step_{step:06d}', 'every_n_train_steps': 'anemoi-by_step-epoch_{epoch:03d}-step_{step:06d}', 'every_n_minutes': 'anemoi-by_time-epoch_{epoch:03d}-step_{step:06d}'}
# [2026-04-13 17:22:17,278][anemoi.training.train.train][INFO] - Plots path: /scratch/dx2/hc7988/anemoi-output/plots/01c343369d05474b9c9f10fa6687843b
# [2026-04-13 17:22:17,278][anemoi.training.train.train][INFO] - Dry run: False
# [2026-04-13 17:22:17,279][anemoi.training.data.datamodule][INFO] - Initializing multi-dataset module with datasets: ['data']
# [2026-04-13 17:22:17,280][anemoi.training.data.datamodule][WARNING] - Falling back rollout to: 1
# [2026-04-13 17:22:17,281][anemoi.training.data.dataset][INFO] - Creating NativeGridDataset...
# [2026-04-13 17:22:17,296][anemoi.utils.config][INFO] - Using environment variable ANEMOI_CONFIG_PATH to override the anemoi config key 'path.'
# [2026-04-13 17:22:17,405][anemoi.training.data.multidataset][INFO] - Timeincrement set to 1 for data with frequency, 21600, and timestep, 21600
# [2026-04-13 17:22:17,407][anemoi.training.data.multidataset][INFO] - Dataset 'data' has 16070 valid indices
# [2026-04-13 17:22:17,407][anemoi.training.data.multidataset][INFO] - MultiDataset has 16070 valid indices after intersection.
# [2026-04-13 17:22:17,407][anemoi.training.data.multidataset][INFO] - MultiDataset initialized with 1 datasets (data), 16070 valid indices each
# [2026-04-13 17:22:17,408][anemoi.training.train.train][INFO] - Dataset 'data' - Number of variables: 23
# [2026-04-13 17:22:17,408][anemoi.training.train.train][INFO] - Dataset 'data' - Variables: ['z_1000', 'z_500', 'z_700', 'z_300', '2t', 't_850', 'tcw', 'z_250', 'cp', 'tp', 'cos_latitude', 'cos_longitude', 'sin_latitude', 'sin_longitude', 'cos_julian_day', 'cos_local_time', 'sin_julian_day', 'sin_local_time', 'insolation', 'lsm', 'sdor', 'slor', 'z']
# [2026-04-13 17:22:17,409][anemoi.training.train.train][INFO] - Dataset 'data' - Total number of prognostic variables: 10
# [2026-04-13 17:22:17,409][anemoi.training.train.train][INFO] - Dataset 'data' - Total number of auxiliary variables: 13
# [2026-04-13 17:22:17,410][anemoi.training.train.train][INFO] - Total GPU count / model group size: 1 - NB: the learning rate will be scaled by this factor!
# [2026-04-13 17:22:17,410][anemoi.training.train.train][INFO] - Effective learning rate: 1.000e-03
# [2026-04-13 17:22:18,742][anemoi.training.diagnostics.callbacks.plot][INFO] - Setting up asynchronous plotting ...
# [2026-04-13 17:22:18,743][anemoi.training.diagnostics.callbacks][INFO] - Using progress bar: <class 'pytorch_lightning.callbacks.progress.tqdm_progress.TQDMProgressBar'>
# [2026-04-13 17:22:18,758][anemoi.models.migrations.migrator][INFO] - Loading migration 1755530253_initial
# [2026-04-13 17:22:18,758][anemoi.models.migrations.migrator][INFO] - Loading migration 1762857427_deprecate_eda
# [2026-04-13 17:22:18,758][anemoi.models.migrations.migrator][INFO] - Loading migration 1762857428_chunking_fix
# [2026-04-13 17:22:18,758][anemoi.models.migrations.migrator][INFO] - Loading migration 1763479917_hardware_schema_update
# [2026-04-13 17:22:18,758][anemoi.models.migrations.migrator][INFO] - Loading migration 1763479918_refactor_mapper
# [2026-04-13 17:22:18,758][anemoi.models.migrations.migrator][INFO] - Loading migration 1767108147_move_to_multiple_datasets
# [2026-04-13 17:22:18,758][anemoi.models.migrations.migrator][INFO] - Loading migration 1773048851_fuse_multiple_perdataset_graphs
# [2026-04-13 17:22:18,768][pytorch_lightning.utilities.rank_zero][INFO] - Using 16bit Automatic Mixed Precision (AMP)
# [2026-04-13 17:22:18,844][pytorch_lightning.utilities.rank_zero][INFO] - GPU available: True (cuda), used: True
# [2026-04-13 17:22:18,844][pytorch_lightning.utilities.rank_zero][INFO] - TPU available: False, using: 0 TPU cores
# [2026-04-13 17:22:18,846][pytorch_lightning.utilities.rank_zero][INFO] - 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# [2026-04-13 17:22:20,505][anemoi.graphs.nodes.builders.from_file][INFO] - Reading the dataset from {'dataset': '/g/data/dk92/data/aifs-ens/aifs-ea-an-oper-0001-mars-o48-2010-2022-6h-v1-toy.zarr', 'frequency': '6h', 'drop': [], 'select': ['z_1000', 'z_500', 'z_700', 'z_300', '2t', 't_850', 'tcw', 'z_250', 'lsm', 'z', 'cp', 'tp', 'cos_latitude', 'cos_longitude', 'sin_latitude', 'sin_longitude', 'cos_julian_day', 'cos_local_time', 'sin_julian_day', 'sin_local_time', 'insolation', 'lsm', 'sdor', 'slor', 'z']}.
# [2026-04-13 17:22:21,018][anemoi.graphs.edges.builders.cutoff][INFO] - Using CutOff-Edges (with radius = 144.6 km [factor=0.60]) between data and hidden.
# [2026-04-13 17:22:21,039][anemoi.graphs.edges.builders.base][WARNING] - The 'torch-cluster' library is not installed.
# Installing 'torch-cluster' can significantly improve performance for graph creation.
# You can install it using:
#     TORCH_VERSION=$(python -c "import torch; print(torch.__version__)")
#     pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH_VERSION}.html
#
# [2026-04-13 17:22:21,372][anemoi.graphs.edges.builders.knn][INFO] - Using KNN-Edges (with 3 nearest neighbours) between hidden and data.
# [2026-04-13 17:22:21,372][anemoi.graphs.edges.builders.base][WARNING] - The 'torch-cluster' library is not installed.
# Installing 'torch-cluster' can significantly improve performance for graph creation.
# You can install it using:
#     TORCH_VERSION=$(python -c "import torch; print(torch.__version__)")
#     pip install torch-cluster -f https://data.pyg.org/whl/torch-${TORCH_VERSION}.html
#
# [2026-04-13 17:22:21,435][anemoi.graphs.create][INFO] - Cleaning graph.
# [2026-04-13 17:22:21,435][anemoi.graphs.create][INFO] - _grid_reference_distance deleted from graph.
# [2026-04-13 17:22:21,435][anemoi.graphs.create][INFO] - _dataset deleted from graph.
# [2026-04-13 17:22:21,436][anemoi.graphs.create][INFO] - _grid_reference_distance deleted from graph.
# [2026-04-13 17:22:21,436][anemoi.graphs.create][WARNING] - No output path specified. The graph will not be saved.
# [2026-04-13 17:22:21,436][lightning_fabric.utilities.seed][INFO] - Seed set to 42000
# [2026-04-13 17:22:21,450][anemoi.training.train.train][INFO] - Initial seed: Rank 0, initial seed 42000, running with random seed: 42000
# [2026-04-13 17:22:27,127][anemoi.training.data.datamodule][WARNING] - Falling back rollout to: 1
# [2026-04-13 17:22:27,164][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_latitude is not normalized.
# [2026-04-13 17:22:27,164][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_longitude is not normalized.
# [2026-04-13 17:22:27,164][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_latitude is not normalized.
# [2026-04-13 17:22:27,164][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_longitude is not normalized.
# [2026-04-13 17:22:27,164][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_julian_day is not normalized.
# [2026-04-13 17:22:27,164][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_local_time is not normalized.
# [2026-04-13 17:22:27,164][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_julian_day is not normalized.
# [2026-04-13 17:22:27,164][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_local_time is not normalized.
# [2026-04-13 17:22:27,164][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: insolation is not normalized.
# [2026-04-13 17:22:27,164][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: lsm is not normalized.
# [2026-04-13 17:22:27,170][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_latitude is not normalized.
# [2026-04-13 17:22:27,170][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_longitude is not normalized.
# [2026-04-13 17:22:27,170][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_latitude is not normalized.
# [2026-04-13 17:22:27,170][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_longitude is not normalized.
# [2026-04-13 17:22:27,170][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_julian_day is not normalized.
# [2026-04-13 17:22:27,170][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: cos_local_time is not normalized.
# [2026-04-13 17:22:27,170][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_julian_day is not normalized.
# [2026-04-13 17:22:27,170][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: sin_local_time is not normalized.
# [2026-04-13 17:22:27,170][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: insolation is not normalized.
# [2026-04-13 17:22:27,170][anemoi.models.preprocessing.normalizer][INFO] - Normalizing: lsm is not normalized.
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib/python3.12/site-packages/anemoi/models/preprocessing/normalizer.py:95: RuntimeWarning: divide by zero encountered in scalar divide
#   _norm_mul[i] = 1 / maximum[i]
# [2026-04-13 17:22:27,266][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-13 17:22:27,266][anemoi.models.layers.utils][INFO] - LayerNorm kernel: torch.nn.LayerNorm.
# [2026-04-13 17:22:27,267][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-13 17:22:27,269][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-13 17:22:27,270][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-13 17:22:27,312][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-13 17:22:27,312][anemoi.models.layers.utils][INFO] - LayerNorm kernel: anemoi.models.layers.normalization.ConditionalLayerNorm.
# [2026-04-13 17:22:27,313][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-13 17:22:27,314][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-13 17:22:27,315][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-13 17:22:27,316][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-13 17:22:27,322][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-13 17:22:27,324][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-13 17:22:27,326][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-13 17:22:27,328][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-13 17:22:27,330][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-13 17:22:27,332][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-13 17:22:27,334][anemoi.models.layers.attention][INFO] - Using scaled_dot_product_attention.
# [2026-04-13 17:22:27,342][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-13 17:22:27,343][anemoi.models.layers.utils][INFO] - LayerNorm kernel: torch.nn.LayerNorm.
# [2026-04-13 17:22:27,343][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-13 17:22:27,344][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-13 17:22:27,345][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-13 17:22:27,352][anemoi.models.layers.utils][INFO] - Linear kernel: torch.nn.Linear.
# [2026-04-13 17:22:27,353][anemoi.models.layers.utils][INFO] - LayerNorm kernel: torch.nn.LayerNorm.
# [2026-04-13 17:22:27,354][anemoi.models.layers.utils][INFO] - Activation kernel: torch.nn.GELU.
# [2026-04-13 17:22:27,355][anemoi.models.layers.utils][INFO] - QueryNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-13 17:22:27,355][anemoi.models.layers.utils][INFO] - KeyNorm kernel: anemoi.models.layers.normalization.AutocastLayerNorm.
# [2026-04-13 17:22:27,356][anemoi.models.layers.ensemble][INFO] - processor noise channels = 4
# [2026-04-13 17:22:27,400][anemoi.training.losses.scalers.variable_level][INFO] - Variable Level Scaling: Applying ReluVariableLevelScaler scaling to pl variables ({'param': ['q', 't', 'u', 'v', 'w', 'z']})
# [2026-04-13 17:22:27,400][anemoi.training.losses.scalers.variable_level][INFO] - with slope = 0.001 and y-intercept/minimum = 0.2.
# [2026-04-13 17:22:27,425][anemoi.training.losses.multiscale][INFO] - Loss smoothing: None
# [2026-04-13 17:22:27,431][anemoi.training.losses.multiscale][INFO] - Loss smoothing: None
# [2026-04-13 17:22:27,431][anemoi.training.train.tasks.base][INFO] - GraphModule with n_step_input=2 and n_step_output=1
# [2026-04-13 17:22:27,432][anemoi.training.train.tasks.ensforecaster][INFO] - Base (config) learning rate: 1.000000e-03 -- Effective learning rate: 1.000000e-03
# [2026-04-13 17:22:27,432][anemoi.training.train.tasks.ensforecaster][INFO] - Ensemble size: per device = 2, per ens-group = 2
# [2026-04-13 17:22:27,432][anemoi.training.train.train][INFO] - The following submodules will NOT be trained: []
# [2026-04-13 17:22:27,434][anemoi.models.utils.compile][INFO] - The following modules will be compiled: []
# [2026-04-13 17:22:27,434][anemoi.training.train.train][INFO] - Recompile limit set to 32
# [2026-04-13 17:22:27,446][lightning_fabric.utilities.distributed][INFO] - Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# [2026-04-13 17:22:27,710][pytorch_lightning.utilities.rank_zero][INFO] - ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# [2026-04-13 17:22:27,742][anemoi.training.diagnostics.mlflow.logger][INFO] - Logging 12 parameters
# [2026-04-13 17:22:27,909][anemoi.training.distributed.strategy][INFO] - Rank 0 model_comm_group_id: 0 model_comm_group: [0] model_comm_group_rank: 0 model_comm_group.size(): 1 reader_group_id: 0 reader_group: [0] reader_group_rank: 0 reader_group_root (global): 0 model_reader_groups: [<torch.distributed.distributed_c10d.ProcessGroup object at 0x14ae25352df0>] reader_groups: [[<torch.distributed.distributed_c10d.ProcessGroup object at 0x14ae25352df0>]]
# [2026-04-13 17:22:28,031][anemoi.training.distributed.strategy][INFO] - Rank 0 ens_comm_group_id: 0 ens_comm_group: [0] ens_comm_group_rank: 0 ens_comm_group_size: 1 ens_comm_group.size(): 1 ens_comm_subgroup_id: 0 ens_comm_subgroup: [0] ens_comm_subgroup_rank: 0 ens_comm_subgroup.size(): 1
# [2026-04-13 17:22:28,031][pytorch_lightning.accelerators.cuda][INFO] - LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# [2026-04-13 17:22:28,069][anemoi.training.train.tasks.base][INFO] - Optimizer initialized: AdamW
# [2026-04-13 17:22:28,069][anemoi.training.train.tasks.base][INFO] - Optimizer settings: {'lr': 0.001, 'betas': [0.9, 0.95], 'eps': 1e-08, 'weight_decay': 0.01, 'amsgrad': False, 'maximize': False, 'foreach': None, 'capturable': False, 'differentiable': False, 'fused': None, 'decoupled_weight_decay': True}
# [2026-04-13 17:22:28,076][lightning_fabric.utilities.seed][INFO] - [rank: 0] Seed set to 42000
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib/python3.12/site-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name    ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model   │ AnemoiModelInterface │  2.6 M │ train │     0 │
# │ 1 │ loss    │ ModuleDict           │      0 │ train │     0 │
# │ 2 │ metrics │ ModuleDict           │      0 │ train │     0 │
# └───┴─────────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 2.6 M
# Non-trainable params: 0
# Total params: 2.6 M
# Total estimated model params size (MB): 10
# Modules in train mode: 272
# Modules in eval mode: 0
# Total FLOPs: 0
# [2026-04-13 17:22:28,139][anemoi.training.diagnostics.mlflow.logger][INFO] - Logging 632 parameters
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s][2026-04-13 17:22:29,435][anemoi.training.data.datamodule][WARNING] - Falling back rollout to: 1
# [2026-04-13 17:22:29,436][anemoi.training.data.dataset][INFO] - Creating NativeGridDataset...
# [2026-04-13 17:22:29,562][anemoi.training.data.multidataset][INFO] - Timeincrement set to 1 for data with frequency, 21600, and timestep, 21600
# [2026-04-13 17:22:29,563][anemoi.training.data.multidataset][INFO] - Dataset 'data' has 1458 valid indices
# [2026-04-13 17:22:29,563][anemoi.training.data.multidataset][INFO] - MultiDataset has 1458 valid indices after intersection.
# [2026-04-13 17:22:29,563][anemoi.training.data.multidataset][INFO] - MultiDataset initialized with 1 datasets (data), 1458 valid indices each
# [2026-04-13 17:22:29,565][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_group_info(): global_rank 0, model_comm_group_id 0, model_comm_group_rank 0, model_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# [2026-04-13 17:22:29,565][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_ens_comm_group_info(): global_rank 0, ens_comm_group_id 0, ens_comm_group_rank 0, ens_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# [2026-04-13 17:22:29,596][anemoi.training.data.multidataset][INFO] - Worker 0 (pid 891900, global_rank 0, model comm group 0)  has low/high range 0 / 183
# [2026-04-13 17:22:29,599][anemoi.training.data.multidataset][INFO] - Worker 0 (validation, pid 891900, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:29,618][anemoi.training.data.multidataset][INFO] - Worker 1 (pid 891901, global_rank 0, model comm group 0)  has low/high range 183 / 366
# [2026-04-13 17:22:29,622][anemoi.training.data.multidataset][INFO] - Worker 1 (validation, pid 891901, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:29,640][anemoi.training.data.multidataset][INFO] - Worker 2 (pid 891902, global_rank 0, model comm group 0)  has low/high range 366 / 548
# [2026-04-13 17:22:29,644][anemoi.training.data.multidataset][INFO] - Worker 2 (validation, pid 891902, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:29,654][anemoi.training.data.multidataset][INFO] - Worker 3 (pid 891903, global_rank 0, model comm group 0)  has low/high range 548 / 730
# [2026-04-13 17:22:29,658][anemoi.training.data.multidataset][INFO] - Worker 3 (validation, pid 891903, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:29,676][anemoi.training.data.multidataset][INFO] - Worker 4 (pid 891904, global_rank 0, model comm group 0)  has low/high range 730 / 912
# [2026-04-13 17:22:29,680][anemoi.training.data.multidataset][INFO] - Worker 4 (validation, pid 891904, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:29,695][anemoi.training.data.multidataset][INFO] - Worker 5 (pid 891905, global_rank 0, model comm group 0)  has low/high range 912 / 1094
# [2026-04-13 17:22:29,699][anemoi.training.data.multidataset][INFO] - Worker 5 (validation, pid 891905, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:29,716][anemoi.training.data.multidataset][INFO] - Worker 6 (pid 891906, global_rank 0, model comm group 0)  has low/high range 1094 / 1276
# [2026-04-13 17:22:29,719][anemoi.training.data.multidataset][INFO] - Worker 6 (validation, pid 891906, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:29,731][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
# [2026-04-13 17:22:29,734][anemoi.training.data.multidataset][INFO] - Worker 7 (pid 891907, global_rank 0, model comm group 0)  has low/high range 1276 / 1458
# [2026-04-13 17:22:29,738][anemoi.training.data.multidataset][INFO] - Worker 7 (validation, pid 891907, base_seed 42000, sanity rnd 0.315034)
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:378: You have overridden `transfer_batch_to_device` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
# /g/data/dx2/hc7988/venvs/home/548/hc7988/Projects/ECMWF/training/2026-ml-bom-training/lib/python3.12/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:378: You have overridden `on_after_batch_transfer` in `LightningModule` but have passed in a `LightningDataModule`. It will use the implementation from `LightningModule` instance.
#
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:   0%|          | 0/6 [00:00<?, ?it/s]
# Sanity Checking DataLoader 0:  17%|█▋        | 1/6 [00:00<00:04,  1.13it/s]
# Sanity Checking DataLoader 0:  33%|███▎      | 2/6 [00:01<00:03,  1.07it/s]
# Sanity Checking DataLoader 0:  50%|█████     | 3/6 [00:02<00:02,  1.20it/s]
# Sanity Checking DataLoader 0:  67%|██████▋   | 4/6 [00:03<00:01,  1.30it/s]
# Sanity Checking DataLoader 0:  83%|████████▎ | 5/6 [00:03<00:00,  1.45it/s]
# Sanity Checking DataLoader 0: 100%|██████████| 6/6 [00:03<00:00,  1.58it/s]
#
# [2026-04-13 17:22:33,565][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_group_info(): global_rank 0, model_comm_group_id 0, model_comm_group_rank 0, model_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# [2026-04-13 17:22:33,566][anemoi.training.data.multidataset][INFO] - NativeGridDataset.set_ens_comm_group_info(): global_rank 0, ens_comm_group_id 0, ens_comm_group_rank 0, ens_comm_num_groups 1, reader_group_rank 0, sample_comm_group_id 0, sample_comm_num_groups 1
# [2026-04-13 17:22:33,604][anemoi.training.data.multidataset][INFO] - Worker 0 (pid 891968, global_rank 0, model comm group 0)  has low/high range 0 / 2009
# [2026-04-13 17:22:33,608][anemoi.training.data.multidataset][INFO] - Worker 0 (training, pid 891968, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:33,625][anemoi.training.data.multidataset][INFO] - Worker 1 (pid 891969, global_rank 0, model comm group 0)  has low/high range 2009 / 4018
# [2026-04-13 17:22:33,628][anemoi.training.data.multidataset][INFO] - Worker 1 (training, pid 891969, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:33,647][anemoi.training.data.multidataset][INFO] - Worker 2 (pid 891970, global_rank 0, model comm group 0)  has low/high range 4018 / 6027
# [2026-04-13 17:22:33,651][anemoi.training.data.multidataset][INFO] - Worker 2 (training, pid 891970, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:33,666][anemoi.training.data.multidataset][INFO] - Worker 3 (pid 891971, global_rank 0, model comm group 0)  has low/high range 6027 / 8036
# [2026-04-13 17:22:33,670][anemoi.training.data.multidataset][INFO] - Worker 3 (training, pid 891971, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:33,688][anemoi.training.data.multidataset][INFO] - Worker 4 (pid 891972, global_rank 0, model comm group 0)  has low/high range 8036 / 10045
# [2026-04-13 17:22:33,692][anemoi.training.data.multidataset][INFO] - Worker 4 (training, pid 891972, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:33,709][anemoi.training.data.multidataset][INFO] - Worker 5 (pid 891973, global_rank 0, model comm group 0)  has low/high range 10045 / 12054
# [2026-04-13 17:22:33,712][anemoi.training.data.multidataset][INFO] - Worker 5 (training, pid 891973, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:33,731][anemoi.training.data.multidataset][INFO] - Worker 6 (pid 891974, global_rank 0, model comm group 0)  has low/high range 12054 / 14062
# [2026-04-13 17:22:33,734][anemoi.training.data.multidataset][INFO] - Worker 6 (training, pid 891974, base_seed 42000, sanity rnd 0.315034)
# [2026-04-13 17:22:33,751][anemoi.training.data.multidataset][INFO] - Worker 7 (pid 891975, global_rank 0, model comm group 0)  has low/high range 14062 / 16070
#
# Training: |          | 0/? [00:00<?, ?it/s][2026-04-13 17:22:33,754][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
# [2026-04-13 17:22:33,756][anemoi.training.data.multidataset][INFO] - Worker 7 (training, pid 891975, base_seed 42000, sanity rnd 0.315034)
#
# Training: |          | 0/? [00:00<?, ?it/s]
# Epoch 0:   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 0:   5%|▌         | 1/20 [00:01<00:33,  0.57it/s]
# Epoch 0:   5%|▌         | 1/20 [00:01<00:33,  0.57it/s, v_num=843b, train_multi_dataset_loss_step=20.40]
# Epoch 0:  10%|█         | 2/20 [00:03<00:32,  0.55it/s, v_num=843b, train_multi_dataset_loss_step=20.40]
# Epoch 0:  10%|█         | 2/20 [00:03<00:32,  0.55it/s, v_num=843b, train_multi_dataset_loss_step=22.00]
# Epoch 0:  15%|█▌        | 3/20 [00:06<00:39,  0.43it/s, v_num=843b, train_multi_dataset_loss_step=22.00]
# Epoch 0:  15%|█▌        | 3/20 [00:06<00:39,  0.43it/s, v_num=843b, train_multi_dataset_loss_step=21.60]
# Epoch 0:  20%|██        | 4/20 [00:10<00:40,  0.40it/s, v_num=843b, train_multi_dataset_loss_step=21.60]
# Epoch 0:  20%|██        | 4/20 [00:10<00:40,  0.40it/s, v_num=843b, train_multi_dataset_loss_step=22.20]
# Epoch 0:  25%|██▌       | 5/20 [00:13<00:40,  0.37it/s, v_num=843b, train_multi_dataset_loss_step=22.20]
# Epoch 0:  25%|██▌       | 5/20 [00:13<00:40,  0.37it/s, v_num=843b, train_multi_dataset_loss_step=21.50]
# Epoch 0:  30%|███       | 6/20 [00:16<00:38,  0.36it/s, v_num=843b, train_multi_dataset_loss_step=21.50]
# Epoch 0:  30%|███       | 6/20 [00:16<00:38,  0.36it/s, v_num=843b, train_multi_dataset_loss_step=20.80]
# Epoch 0:  35%|███▌      | 7/20 [00:19<00:36,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=20.80]
# Epoch 0:  35%|███▌      | 7/20 [00:19<00:36,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=20.10]
# Epoch 0:  40%|████      | 8/20 [00:23<00:34,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=20.10]
# Epoch 0:  40%|████      | 8/20 [00:23<00:34,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=19.80]
# Epoch 0:  45%|████▌     | 9/20 [00:26<00:32,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=19.80]
# Epoch 0:  45%|████▌     | 9/20 [00:26<00:32,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=20.40]
# Epoch 0:  50%|█████     | 10/20 [00:29<00:29,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=20.40]
# Epoch 0:  50%|█████     | 10/20 [00:29<00:29,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=18.70]
# Epoch 0:  55%|█████▌    | 11/20 [00:33<00:27,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=18.70]
# Epoch 0:  55%|█████▌    | 11/20 [00:33<00:27,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=18.70]
# Epoch 0:  60%|██████    | 12/20 [00:36<00:24,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=18.70]
# Epoch 0:  60%|██████    | 12/20 [00:36<00:24,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=18.40]
# Epoch 0:  65%|██████▌   | 13/20 [00:39<00:21,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=18.40]
# Epoch 0:  65%|██████▌   | 13/20 [00:39<00:21,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=18.70]
# Epoch 0:  70%|███████   | 14/20 [00:42<00:18,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=18.70]
# Epoch 0:  70%|███████   | 14/20 [00:42<00:18,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=18.00]
# Epoch 0:  75%|███████▌  | 15/20 [00:45<00:15,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=18.00]
# Epoch 0:  75%|███████▌  | 15/20 [00:45<00:15,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=16.50]
# Epoch 0:  80%|████████  | 16/20 [00:48<00:12,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=16.50]
# Epoch 0:  80%|████████  | 16/20 [00:48<00:12,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=16.20]
# Epoch 0:  85%|████████▌ | 17/20 [00:50<00:08,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=16.20]
# Epoch 0:  85%|████████▌ | 17/20 [00:50<00:08,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=15.60]
# Epoch 0:  90%|█████████ | 18/20 [00:53<00:05,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=15.60]
# Epoch 0:  90%|█████████ | 18/20 [00:53<00:05,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=14.20]
# Epoch 0:  95%|█████████▌| 19/20 [00:56<00:02,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=14.20]
# Epoch 0:  95%|█████████▌| 19/20 [00:56<00:02,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=13.20]
# Epoch 0: 100%|██████████| 20/20 [00:59<00:00,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=13.20]
# Epoch 0: 100%|██████████| 20/20 [00:59<00:00,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=12.60]
#
# Validation: |          | 0/? [00:00<?, ?it/s][2026-04-13 17:23:40,048][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/50 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   2%|▏         | 1/50 [00:00<00:37,  1.31it/s]
#
# Validation DataLoader 0:   4%|▍         | 2/50 [00:01<00:38,  1.24it/s]
#
# Validation DataLoader 0:   6%|▌         | 3/50 [00:02<00:37,  1.26it/s]
#
# Validation DataLoader 0:   8%|▊         | 4/50 [00:03<00:34,  1.33it/s]
#
# Validation DataLoader 0:  10%|█         | 5/50 [00:03<00:34,  1.32it/s]
#
# Validation DataLoader 0:  12%|█▏        | 6/50 [00:04<00:32,  1.36it/s]
#
# Validation DataLoader 0:  14%|█▍        | 7/50 [00:05<00:31,  1.35it/s]
#
# Validation DataLoader 0:  16%|█▌        | 8/50 [00:05<00:30,  1.38it/s]
#
# Validation DataLoader 0:  18%|█▊        | 9/50 [00:06<00:29,  1.37it/s]
#
# Validation DataLoader 0:  20%|██        | 10/50 [00:07<00:28,  1.39it/s]
#
# Validation DataLoader 0:  22%|██▏       | 11/50 [00:07<00:28,  1.38it/s]
#
# Validation DataLoader 0:  24%|██▍       | 12/50 [00:08<00:27,  1.39it/s]
#
# Validation DataLoader 0:  26%|██▌       | 13/50 [00:09<00:26,  1.39it/s]
#
# Validation DataLoader 0:  28%|██▊       | 14/50 [00:09<00:25,  1.44it/s]
#
# Validation DataLoader 0:  30%|███       | 15/50 [00:10<00:23,  1.49it/s]
#
# Validation DataLoader 0:  32%|███▏      | 16/50 [00:10<00:22,  1.53it/s]
#
# Validation DataLoader 0:  34%|███▍      | 17/50 [00:10<00:20,  1.57it/s]
#
# Validation DataLoader 0:  36%|███▌      | 18/50 [00:11<00:19,  1.61it/s]
#
# Validation DataLoader 0:  38%|███▊      | 19/50 [00:11<00:18,  1.65it/s]
#
# Validation DataLoader 0:  40%|████      | 20/50 [00:12<00:18,  1.64it/s]
#
# Validation DataLoader 0:  42%|████▏     | 21/50 [00:12<00:17,  1.67it/s]
#
# Validation DataLoader 0:  44%|████▍     | 22/50 [00:12<00:16,  1.71it/s]
#
# Validation DataLoader 0:  46%|████▌     | 23/50 [00:13<00:15,  1.71it/s]
#
# Validation DataLoader 0:  48%|████▊     | 24/50 [00:14<00:15,  1.66it/s]
#
# Validation DataLoader 0:  50%|█████     | 25/50 [00:15<00:15,  1.65it/s]
#
# Validation DataLoader 0:  52%|█████▏    | 26/50 [00:16<00:14,  1.61it/s]
#
# Validation DataLoader 0:  54%|█████▍    | 27/50 [00:16<00:14,  1.60it/s]
#
# Validation DataLoader 0:  56%|█████▌    | 28/50 [00:17<00:13,  1.61it/s]
#
# Validation DataLoader 0:  58%|█████▊    | 29/50 [00:18<00:13,  1.58it/s]
#
# Validation DataLoader 0:  60%|██████    | 30/50 [00:18<00:12,  1.58it/s]
#
# Validation DataLoader 0:  62%|██████▏   | 31/50 [00:20<00:12,  1.55it/s]
#
# Validation DataLoader 0:  64%|██████▍   | 32/50 [00:20<00:11,  1.55it/s]
#
# Validation DataLoader 0:  66%|██████▌   | 33/50 [00:21<00:11,  1.52it/s]
#
# Validation DataLoader 0:  68%|██████▊   | 34/50 [00:22<00:10,  1.52it/s]
#
# Validation DataLoader 0:  70%|███████   | 35/50 [00:23<00:10,  1.50it/s]
#
# Validation DataLoader 0:  72%|███████▏  | 36/50 [00:24<00:09,  1.50it/s]
#
# Validation DataLoader 0:  74%|███████▍  | 37/50 [00:25<00:08,  1.48it/s]
#
# Validation DataLoader 0:  76%|███████▌  | 38/50 [00:25<00:08,  1.47it/s]
#
# Validation DataLoader 0:  78%|███████▊  | 39/50 [00:26<00:07,  1.46it/s]
#
# Validation DataLoader 0:  80%|████████  | 40/50 [00:27<00:06,  1.46it/s]
#
# Validation DataLoader 0:  82%|████████▏ | 41/50 [00:28<00:06,  1.44it/s]
#
# Validation DataLoader 0:  84%|████████▍ | 42/50 [00:29<00:05,  1.44it/s]
#
# Validation DataLoader 0:  86%|████████▌ | 43/50 [00:30<00:04,  1.43it/s]
#
# Validation DataLoader 0:  88%|████████▊ | 44/50 [00:30<00:04,  1.43it/s]
#
# Validation DataLoader 0:  90%|█████████ | 45/50 [00:31<00:03,  1.41it/s]
#
# Validation DataLoader 0:  92%|█████████▏| 46/50 [00:32<00:02,  1.41it/s]
#
# Validation DataLoader 0:  94%|█████████▍| 47/50 [00:33<00:02,  1.40it/s]
#
# Validation DataLoader 0:  96%|█████████▌| 48/50 [00:34<00:01,  1.40it/s]
#
# Validation DataLoader 0:  98%|█████████▊| 49/50 [00:35<00:00,  1.39it/s]
#
# Validation DataLoader 0: 100%|██████████| 50/50 [00:35<00:00,  1.39it/s]
#
#
# Epoch 0: 100%|██████████| 20/20 [01:35<00:00,  0.21it/s, v_num=843b, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20][2026-04-13 17:24:17,817][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/01c343369d05474b9c9f10fa6687843b/inference-anemoi-by_epoch-epoch_000-step_000020.ckpt
# [2026-04-13 17:24:17,818][anemoi.utils.checkpoints][INFO] - Saving metadata to inference-anemoi-by_epoch-epoch_000-step_000020/anemoi-metadata/anemoi.json
# [2026-04-13 17:24:17,820][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to inference-anemoi-by_epoch-epoch_000-step_000020/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:24:17,820][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to inference-anemoi-by_epoch-epoch_000-step_000020/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:24:18,003][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/01c343369d05474b9c9f10fa6687843b/anemoi-by_epoch-epoch_000-step_000020.ckpt
# [2026-04-13 17:24:18,003][anemoi.utils.checkpoints][INFO] - Saving metadata to archive/anemoi-metadata/anemoi.json
# [2026-04-13 17:24:18,004][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to archive/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:24:18,005][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to archive/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:24:19,475][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/01c343369d05474b9c9f10fa6687843b/inference-last.ckpt
# [2026-04-13 17:24:19,475][anemoi.utils.checkpoints][INFO] - Saving metadata to inference-last/anemoi-metadata/anemoi.json
# [2026-04-13 17:24:19,476][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to inference-last/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:24:19,476][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to inference-last/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:24:19,731][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/01c343369d05474b9c9f10fa6687843b/last.ckpt
# [2026-04-13 17:24:19,731][anemoi.utils.checkpoints][INFO] - Saving metadata to archive/anemoi-metadata/anemoi.json
# [2026-04-13 17:24:19,732][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to archive/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:24:19,732][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to archive/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
#
# Epoch 0: 100%|██████████| 20/20 [01:39<00:00,  0.20it/s, v_num=843b, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 0:   0%|          | 0/20 [00:00<?, ?it/s, v_num=843b, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:   0%|          | 0/20 [00:00<?, ?it/s, v_num=843b, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:   5%|▌         | 1/20 [00:03<01:03,  0.30it/s, v_num=843b, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:   5%|▌         | 1/20 [00:03<01:03,  0.30it/s, v_num=843b, train_multi_dataset_loss_step=14.40, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  10%|█         | 2/20 [00:06<00:56,  0.32it/s, v_num=843b, train_multi_dataset_loss_step=14.40, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  10%|█         | 2/20 [00:06<00:56,  0.32it/s, v_num=843b, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  15%|█▌        | 3/20 [00:09<00:51,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=12.60, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  15%|█▌        | 3/20 [00:09<00:51,  0.33it/s, v_num=843b, train_multi_dataset_loss_step=14.10, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  20%|██        | 4/20 [00:11<00:47,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=14.10, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  20%|██        | 4/20 [00:11<00:47,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=12.40, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  25%|██▌       | 5/20 [00:14<00:43,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=12.40, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  25%|██▌       | 5/20 [00:14<00:43,  0.34it/s, v_num=843b, train_multi_dataset_loss_step=12.00, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  30%|███       | 6/20 [00:17<00:40,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=12.00, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  30%|███       | 6/20 [00:17<00:40,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.210, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  35%|███▌      | 7/20 [00:20<00:37,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.210, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  35%|███▌      | 7/20 [00:20<00:37,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.760, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  40%|████      | 8/20 [00:22<00:34,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.760, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  40%|████      | 8/20 [00:22<00:34,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.710, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  45%|████▌     | 9/20 [00:25<00:31,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.710, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  45%|████▌     | 9/20 [00:25<00:31,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.240, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  50%|█████     | 10/20 [00:28<00:28,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.240, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  50%|█████     | 10/20 [00:28<00:28,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.290, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  55%|█████▌    | 11/20 [00:31<00:25,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.290, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  55%|█████▌    | 11/20 [00:31<00:25,  0.35it/s, v_num=843b, train_multi_dataset_loss_step=9.490, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  60%|██████    | 12/20 [00:33<00:22,  0.36it/s, v_num=843b, train_multi_dataset_loss_step=9.490, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  60%|██████    | 12/20 [00:33<00:22,  0.36it/s, v_num=843b, train_multi_dataset_loss_step=9.060, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  65%|██████▌   | 13/20 [00:35<00:18,  0.37it/s, v_num=843b, train_multi_dataset_loss_step=9.060, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  65%|██████▌   | 13/20 [00:35<00:18,  0.37it/s, v_num=843b, train_multi_dataset_loss_step=8.430, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  70%|███████   | 14/20 [00:36<00:15,  0.38it/s, v_num=843b, train_multi_dataset_loss_step=8.430, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# Epoch 1:  70%|███████   | 14/20 [00:36<00:15,  0.38it/s, v_num=843b, train_multi_dataset_loss_step=8.740, val_multi_dataset_loss_step=14.40, val_multi_dataset_loss_epoch=13.20, train_multi_dataset_loss_epoch=18.50]
# ...
# Epoch 7:  45%|████▌     | 9/20 [00:24<00:30,  0.36it/s, v_num=843b, train_multi_dataset_loss_step=3.670, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  50%|█████     | 10/20 [00:27<00:27,  0.36it/s, v_num=843b, train_multi_dataset_loss_step=3.670, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  50%|█████     | 10/20 [00:27<00:27,  0.36it/s, v_num=843b, train_multi_dataset_loss_step=4.300, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  55%|█████▌    | 11/20 [00:29<00:23,  0.38it/s, v_num=843b, train_multi_dataset_loss_step=4.300, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  55%|█████▌    | 11/20 [00:29<00:23,  0.38it/s, v_num=843b, train_multi_dataset_loss_step=4.040, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  60%|██████    | 12/20 [00:30<00:20,  0.39it/s, v_num=843b, train_multi_dataset_loss_step=4.040, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  60%|██████    | 12/20 [00:30<00:20,  0.39it/s, v_num=843b, train_multi_dataset_loss_step=3.440, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  65%|██████▌   | 13/20 [00:33<00:17,  0.39it/s, v_num=843b, train_multi_dataset_loss_step=3.440, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  65%|██████▌   | 13/20 [00:33<00:17,  0.39it/s, v_num=843b, train_multi_dataset_loss_step=3.020, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  70%|███████   | 14/20 [00:36<00:15,  0.38it/s, v_num=843b, train_multi_dataset_loss_step=3.020, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  70%|███████   | 14/20 [00:36<00:15,  0.38it/s, v_num=843b, train_multi_dataset_loss_step=3.130, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  75%|███████▌  | 15/20 [00:39<00:13,  0.38it/s, v_num=843b, train_multi_dataset_loss_step=3.130, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  75%|███████▌  | 15/20 [00:39<00:13,  0.38it/s, v_num=843b, train_multi_dataset_loss_step=3.240, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  80%|████████  | 16/20 [00:43<00:10,  0.37it/s, v_num=843b, train_multi_dataset_loss_step=3.240, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  80%|████████  | 16/20 [00:43<00:10,  0.37it/s, v_num=843b, train_multi_dataset_loss_step=4.030, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  85%|████████▌ | 17/20 [00:44<00:07,  0.38it/s, v_num=843b, train_multi_dataset_loss_step=4.030, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  85%|████████▌ | 17/20 [00:44<00:07,  0.38it/s, v_num=843b, train_multi_dataset_loss_step=3.500, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  90%|█████████ | 18/20 [00:46<00:05,  0.39it/s, v_num=843b, train_multi_dataset_loss_step=3.500, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  90%|█████████ | 18/20 [00:46<00:05,  0.39it/s, v_num=843b, train_multi_dataset_loss_step=3.900, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  95%|█████████▌| 19/20 [00:47<00:02,  0.40it/s, v_num=843b, train_multi_dataset_loss_step=3.900, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7:  95%|█████████▌| 19/20 [00:47<00:02,  0.40it/s, v_num=843b, train_multi_dataset_loss_step=3.490, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7: 100%|██████████| 20/20 [00:49<00:00,  0.40it/s, v_num=843b, train_multi_dataset_loss_step=3.490, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
# Epoch 7: 100%|██████████| 20/20 [00:49<00:00,  0.40it/s, v_num=843b, train_multi_dataset_loss_step=3.660, val_multi_dataset_loss_step=4.010, val_multi_dataset_loss_epoch=3.750, train_multi_dataset_loss_epoch=4.080]
#
# Validation: |          | 0/? [00:00<?, ?it/s][2026-04-13 17:35:04,777][anemoi.models.data_indices.collection][INFO] - The order of the variables in the model matches the order in the data.
#
#
# Validation: |          | 0/? [00:00<?, ?it/s]
#
# Validation DataLoader 0:   0%|          | 0/50 [00:00<?, ?it/s]
#
# Validation DataLoader 0:   2%|▏         | 1/50 [00:00<00:18,  2.66it/s]
#
# Validation DataLoader 0:   4%|▍         | 2/50 [00:00<00:22,  2.13it/s]
#
# Validation DataLoader 0:   6%|▌         | 3/50 [00:01<00:20,  2.30it/s]
#
# Validation DataLoader 0:   8%|▊         | 4/50 [00:01<00:19,  2.41it/s]
#
# Validation DataLoader 0:  10%|█         | 5/50 [00:02<00:18,  2.48it/s]
#
# Validation DataLoader 0:  12%|█▏        | 6/50 [00:02<00:17,  2.53it/s]
#
# Validation DataLoader 0:  14%|█▍        | 7/50 [00:02<00:16,  2.56it/s]
#
# Validation DataLoader 0:  16%|█▌        | 8/50 [00:03<00:16,  2.59it/s]
#
# Validation DataLoader 0:  18%|█▊        | 9/50 [00:03<00:15,  2.61it/s]
#
# Validation DataLoader 0:  20%|██        | 10/50 [00:03<00:15,  2.63it/s]
#
# Validation DataLoader 0:  22%|██▏       | 11/50 [00:04<00:14,  2.64it/s]
#
# Validation DataLoader 0:  24%|██▍       | 12/50 [00:04<00:14,  2.66it/s]
#
# Validation DataLoader 0:  26%|██▌       | 13/50 [00:04<00:13,  2.67it/s]
#
# Validation DataLoader 0:  28%|██▊       | 14/50 [00:05<00:13,  2.68it/s]
#
# Validation DataLoader 0:  30%|███       | 15/50 [00:05<00:13,  2.68it/s]
#
# Validation DataLoader 0:  32%|███▏      | 16/50 [00:05<00:12,  2.69it/s]
#
# Validation DataLoader 0:  34%|███▍      | 17/50 [00:06<00:12,  2.70it/s]
#
# Validation DataLoader 0:  36%|███▌      | 18/50 [00:06<00:11,  2.70it/s]
#
# Validation DataLoader 0:  38%|███▊      | 19/50 [00:07<00:11,  2.71it/s]
#
# Validation DataLoader 0:  40%|████      | 20/50 [00:07<00:11,  2.71it/s]
#
# Validation DataLoader 0:  42%|████▏     | 21/50 [00:07<00:10,  2.71it/s]
#
# Validation DataLoader 0:  44%|████▍     | 22/50 [00:08<00:10,  2.71it/s]
#
# Validation DataLoader 0:  46%|████▌     | 23/50 [00:08<00:09,  2.72it/s]
#
# Validation DataLoader 0:  48%|████▊     | 24/50 [00:08<00:09,  2.72it/s]
#
# Validation DataLoader 0:  50%|█████     | 25/50 [00:09<00:09,  2.72it/s]
#
# Validation DataLoader 0:  52%|█████▏    | 26/50 [00:09<00:08,  2.73it/s]
#
# Validation DataLoader 0:  54%|█████▍    | 27/50 [00:09<00:08,  2.73it/s]
#
# Validation DataLoader 0:  56%|█████▌    | 28/50 [00:10<00:08,  2.73it/s]
#
# Validation DataLoader 0:  58%|█████▊    | 29/50 [00:10<00:07,  2.73it/s]
#
# Validation DataLoader 0:  60%|██████    | 30/50 [00:10<00:07,  2.74it/s]
#
# Validation DataLoader 0:  62%|██████▏   | 31/50 [00:11<00:06,  2.74it/s]
#
# Validation DataLoader 0:  64%|██████▍   | 32/50 [00:11<00:06,  2.74it/s]
#
# Validation DataLoader 0:  66%|██████▌   | 33/50 [00:12<00:06,  2.74it/s]
#
# Validation DataLoader 0:  68%|██████▊   | 34/50 [00:12<00:05,  2.74it/s]
#
# Validation DataLoader 0:  70%|███████   | 35/50 [00:12<00:05,  2.74it/s]
#
# Validation DataLoader 0:  72%|███████▏  | 36/50 [00:13<00:05,  2.74it/s]
#
# Validation DataLoader 0:  74%|███████▍  | 37/50 [00:13<00:04,  2.75it/s]
#
# Validation DataLoader 0:  76%|███████▌  | 38/50 [00:13<00:04,  2.75it/s]
#
# Validation DataLoader 0:  78%|███████▊  | 39/50 [00:14<00:04,  2.75it/s]
#
# Validation DataLoader 0:  80%|████████  | 40/50 [00:14<00:03,  2.75it/s]
#
# Validation DataLoader 0:  82%|████████▏ | 41/50 [00:14<00:03,  2.75it/s]
#
# Validation DataLoader 0:  84%|████████▍ | 42/50 [00:15<00:02,  2.75it/s]
#
# Validation DataLoader 0:  86%|████████▌ | 43/50 [00:15<00:02,  2.75it/s]
#
# Validation DataLoader 0:  88%|████████▊ | 44/50 [00:15<00:02,  2.75it/s]
#
# Validation DataLoader 0:  90%|█████████ | 45/50 [00:16<00:01,  2.75it/s]
#
# Validation DataLoader 0:  92%|█████████▏| 46/50 [00:16<00:01,  2.75it/s]
#
# Validation DataLoader 0:  94%|█████████▍| 47/50 [00:17<00:01,  2.76it/s]
#
# Validation DataLoader 0:  96%|█████████▌| 48/50 [00:17<00:00,  2.76it/s]
#
# Validation DataLoader 0:  98%|█████████▊| 49/50 [00:17<00:00,  2.76it/s]
#
# Validation DataLoader 0: 100%|██████████| 50/50 [00:18<00:00,  2.76it/s]
#
#
# Epoch 7: 100%|██████████| 20/20 [01:07<00:00,  0.30it/s, v_num=843b, train_multi_dataset_loss_step=3.660, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=4.080][2026-04-13 17:35:24,491][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/01c343369d05474b9c9f10fa6687843b/inference-anemoi-by_epoch-epoch_007-step_000160.ckpt
# [2026-04-13 17:35:24,491][anemoi.utils.checkpoints][INFO] - Saving metadata to inference-anemoi-by_epoch-epoch_007-step_000160/anemoi-metadata/anemoi.json
# [2026-04-13 17:35:24,492][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to inference-anemoi-by_epoch-epoch_007-step_000160/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:35:24,492][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to inference-anemoi-by_epoch-epoch_007-step_000160/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:35:24,702][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/01c343369d05474b9c9f10fa6687843b/anemoi-by_epoch-epoch_007-step_000160.ckpt
# [2026-04-13 17:35:24,702][anemoi.utils.checkpoints][INFO] - Saving metadata to archive/anemoi-metadata/anemoi.json
# [2026-04-13 17:35:24,704][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to archive/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:35:24,704][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to archive/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:35:26,454][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/01c343369d05474b9c9f10fa6687843b/inference-last.ckpt
# [2026-04-13 17:35:26,454][anemoi.utils.checkpoints][INFO] - Saving metadata to inference-last/anemoi-metadata/anemoi.json
# [2026-04-13 17:35:26,455][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to inference-last/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:35:26,455][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to inference-last/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:35:26,668][anemoi.utils.checkpoints][INFO] - Adding extra information to checkpoint /scratch/dx2/hc7988/anemoi-output/checkpoint/01c343369d05474b9c9f10fa6687843b/last.ckpt
# [2026-04-13 17:35:26,668][anemoi.utils.checkpoints][INFO] - Saving metadata to archive/anemoi-metadata/anemoi.json
# [2026-04-13 17:35:26,669][anemoi.utils.checkpoints][INFO] - Saving supporting array `latitudes` to archive/anemoi-metadata/data/latitudes.numpy (shape=(10944,), dtype=float64)
# [2026-04-13 17:35:26,669][anemoi.utils.checkpoints][INFO] - Saving supporting array `longitudes` to archive/anemoi-metadata/data/longitudes.numpy (shape=(10944,), dtype=float64)
#
# Epoch 7: 100%|██████████| 20/20 [01:11<00:00,  0.28it/s, v_num=843b, train_multi_dataset_loss_step=3.660, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 7:   0%|          | 0/20 [00:00<?, ?it/s, v_num=843b, train_multi_dataset_loss_step=3.660, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:   0%|          | 0/20 [00:00<?, ?it/s, v_num=843b, train_multi_dataset_loss_step=3.660, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:   5%|▌         | 1/20 [00:01<00:30,  0.61it/s, v_num=843b, train_multi_dataset_loss_step=3.660, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:   5%|▌         | 1/20 [00:01<00:30,  0.61it/s, v_num=843b, train_multi_dataset_loss_step=4.080, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  10%|█         | 2/20 [00:03<00:28,  0.63it/s, v_num=843b, train_multi_dataset_loss_step=4.080, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  10%|█         | 2/20 [00:03<00:28,  0.63it/s, v_num=843b, train_multi_dataset_loss_step=3.440, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  15%|█▌        | 3/20 [00:04<00:26,  0.63it/s, v_num=843b, train_multi_dataset_loss_step=3.440, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  15%|█▌        | 3/20 [00:04<00:26,  0.63it/s, v_num=843b, train_multi_dataset_loss_step=4.190, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  20%|██        | 4/20 [00:06<00:25,  0.63it/s, v_num=843b, train_multi_dataset_loss_step=4.190, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  20%|██        | 4/20 [00:06<00:25,  0.63it/s, v_num=843b, train_multi_dataset_loss_step=3.470, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  25%|██▌       | 5/20 [00:07<00:23,  0.64it/s, v_num=843b, train_multi_dataset_loss_step=3.470, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  25%|██▌       | 5/20 [00:07<00:23,  0.64it/s, v_num=843b, train_multi_dataset_loss_step=3.550, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  30%|███       | 6/20 [00:09<00:21,  0.64it/s, v_num=843b, train_multi_dataset_loss_step=3.550, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  30%|███       | 6/20 [00:09<00:21,  0.64it/s, v_num=843b, train_multi_dataset_loss_step=3.570, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# Epoch 8:  35%|███▌      | 7/20 [00:10<00:20,  0.64it/s, v_num=843b, train_multi_dataset_loss_step=3.570, val_multi_dataset_loss_step=4.180, val_multi_dataset_loss_epoch=3.690, train_multi_dataset_loss_epoch=3.630]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 31
#      27     universal_newlines=True
#      28 )
#      29
#      30 # Stream output
# ---> 31 for line in iter(process.stdout.readline, ''):
#      32     if line:
#      33         print(line.rstrip())  # Print immediately to Jupyter cell
#      34
#
# KeyboardInterrupt:

# %% [markdown]
# ## Monitoring and Results
#
# ### MLflow logging
#
# Several metrics and parameters are logged during training. Here, we use MLflow to log results offline.
#
# In the following we use the MLflow API to plot some key metrics during training, such as:
#
# - **Training Loss**: The AlmostFairKernelCRPS loss should decrease over time
# - **Validation Metrics**: Similar to training loss, calculated on validation data
#
# *Note:* Typically the logging is done to a server and can be used interactively on a website.

# %% [markdown]
# ## Server logging
#
# Mlflow logs can be viewed in a web interface, below we skip this and directly retrieve, but if you want to do see it in that ui, move to the logging directory within this environment, and run `mlflow server`
#
# ```bash
# cd /scratch/$PROJECT/$USER/anemoi-outputs/logs/mlflow
# mlflow server
# ```

# %%
import mlflow
import pandas as pd
import matplotlib.pyplot as plt

run_id="01c343369d05474b9c9f10fa6687843b" # CHANGE THIS TO YOUR RUN ID

# Start mlflow client and load run
client = mlflow.tracking.MlflowClient(tracking_uri=f"file:///scratch/{os.getenv("PROJECT")}/{os.getenv("USER")}/anemoi-output/logs/mlflow")
run = client.get_run(run_id)

print(f"Run name: {run.info.run_name}")
print("Logged metrics:")
print("=" * 50)
for k in run.data.metrics.keys():
    print(k)
# Out:
# Run name: ac7ff2c3-ea1d-44a8-a346-1cde05e34a66
# Logged metrics:
# ==================================================
# val_multi_dataset_loss_step
# lr-AdamW
# epoch
# rollout
# val_multi_dataset_loss_epoch
# train_multi_dataset_loss_epoch
# val_data_MultiscaleLossWrapper_loss_scale_0
# train_multi_dataset_loss_step
# system/system_memory_total_megabytes
# system/gpu_memory_total_megabytes
# system/disk_usage_megabytes
# system/gpu_0_power_usage_watts
# system/system_memory_usage_megabytes
# system/gpu_0_memory_usage_megabytes
# system/cpu_utilization_percentage
# system/disk_available_megabytes
# system/gpu_0_pcie_tx_megabytes
# system/gpu_0_utilization_percentage
# system/disk_usage_percentage
# system/network_transmit_megabytes
# system/system_memory_usage_percentage
# system/gpu_0_pcie_rx_megabytes
# system/network_receive_megabytes
# system/gpu_0_power_usage_percentage
# system/gpu_0_memory_usage_percentage
# val_data_multiscale_metric/data/sfc_tp/1_scale_0
# val_data_multiscale_metric/data/t_850/1_scale_0
# val_data_multiscale_metric/data/pl_t/1_scale_0
# val_data_multiscale_metric/data/z_500/1_scale_0
# val_data_multiscale_metric/data/all/1_scale_0
# val_data_multiscale_metric/data/pl_z/1_scale_0
# val_data_multiscale_metric/data/sfc_cp/1_scale_0
# val_data_multiscale_metric/data/sfc_tcw/1_scale_0
# val_data_multiscale_metric/data/sfc_2t/1_scale_0
# val_data_fkcrps_metric/data/sfc_tp/1_scale_0
# val_data_fkcrps_metric/data/t_850/1_scale_0
# val_data_fkcrps_metric/data/pl_t/1_scale_0
# val_data_fkcrps_metric/data/z_500/1_scale_0
# val_data_fkcrps_metric/data/all/1_scale_0
# val_data_fkcrps_metric/data/pl_z/1_scale_0
# val_data_fkcrps_metric/data/sfc_cp/1_scale_0
# val_data_fkcrps_metric/data/sfc_tcw/1_scale_0
# val_data_fkcrps_metric/data/sfc_2t/1_scale_0

# %%
# Plotting,
metric_names = ['train_multi_dataset_loss_step', 'val_multi_dataset_loss_epoch']

# Load data into DataFrame
data = []
for metric in metric_names:
    for entry in client.get_metric_history(run_id, metric):
        data.append({'metric': metric, 'step': entry.step, 'value': entry.value, 'time': entry.timestamp})
df = pd.DataFrame(data)

# Plot all metrics
fig, ax = plt.subplots()
for metric in df['metric'].unique():
    metric_data = df[df['metric'] == metric].sort_values('step')
    ax.plot(metric_data['step'], metric_data['value'], '-o', label=metric)
ax.legend()
ax.set_xlabel('steps')
ax.set_ylabel('loss')
# Out:
# Text(0, 0.5, 'loss')

# %% [markdown]
# ### Task 1: Change the number of ensemble members
#
# Adapt the training config and retrain the model with:
#    - a larger number of ensemble members, e.g. `ensemble_size_per_device=4`
#    - train the model for longer by increasing the number of iterations (`max_steps`) and removing the batch limit
#
# **Questions**
# - How does your loss change with the same number of steps?
# - How much longer does the training take per iteration?
# - What happens if you choose a large number of ensemble members?
#
# ***Note***:
#
# You do not need to do the training in the notebook. You can run on the console with:
# ```
# anemoi-training train --config-path PATH-TO-YOUR-CONFIG-FOLDER --config-name aifs_ens_minimal_config
# ```
#
# #### Task 1.1: Alter the config
#
# Throughout the top level config, are various `ACTIVITY:` prompts which show parts you can easily modify to alter the training behaviour, explore these and design an experiment.

# %% [markdown]
# ### (Optional) Task 2: Inference of your model
#
# Run inference on the model you have trained. For that, go back to the Jupyter notebook `../4-run-AIFS/inference_aifs-ens.ipynb` and import your used checkpoint.
#
# ***Note:***
#
# You need to adapt,
# 1. The resolution of the data for your input fields to O48
#
# ```
# GRID_RESOLUTION = "O48"
# PARAM_SFC = ["2t", 'z', 'lsm', "tcw", "sdor", "slor"]
# PARAM_PL = ["gh", "t"]
# LEVELS = [1000, 850, 700, 500, 300, 250]
# ```
#
# 2. Select only the input fields you need, i.e. ['z_1000', 'z_500', 'z_700', 'z_300', '2t', 't_850', 'tcw', 'z_250', 'lsm', 'z', 'sdor', 'slor']
#
#
# In case you were not able to train the checkpoint. You can find a checkpoint here:
# PUT_GADI_CHECKPOINT_LOCATION_HERE
